# %%
# !nvidia-smi
# Out:
# Sat Jan 20 18:14:27 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !pip install gradio -q
# !pip install whisper
import whisper
# !pip install openai-whisper -U
from whisper.utils import WriteVTT
# Out:
# Requirement already satisfied: whisper in /usr/local/lib/python3.10/dist-packages (1.1.10)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from whisper) (1.16.0)
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.10/dist-packages (20231117)
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.1.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (1.23.5)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (2.1.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (4.66.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (10.1.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.10/dist-packages (from openai-whisper) (0.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper) (3.13.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2023.6.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper) (2.31.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper) (2023.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper) (1.3.0)

# %%
model = whisper.load_model("medium")

# %%
url = 'https://podcasts.google.com/feed/aHR0cHM6Ly9mZWVkcy5zaW1wbGVjYXN0LmNvbS9kSG9vaFZOSA/episode/Y2M1NjEyYTMtMTc3MS00MmIxLTgyNzQtZmYxNWI3YWU5MGI2?sa=X&ved=0CAUQkfYCahgKEwioi4z4tOyDAxUAAAAAHQAAAAAQpAM'

# %%
import requests

# %%
content = requests.get(url)

# %%
from bs4 import BeautifulSoup
import re

# %%
soup = BeautifulSoup(content.text)

# %%
podcast_url = re.findall("(?P<url>\;https?://[^\s]+)", content.text)[0].split(';')[1]

# %%
podcast_url
# Out:
# 'https://chtbl.com/track/9E9755/arttrk.com/p/ST44R/pdrl.fm/f3efd0/stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3?aid=rss_feed&amp'

# %%
# !wget -O podcast.mp3 {podcast_url}
# Out:
# /bin/bash: line 1: amp: command not found
# --2024-01-20 18:41:49--  https://chtbl.com/track/9E9755/arttrk.com/p/ST44R/pdrl.fm/f3efd0/stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3?aid=rss_feed
# Resolving chtbl.com (chtbl.com)... 52.84.162.124, 52.84.162.107, 52.84.162.79, ...
# Connecting to chtbl.com (chtbl.com)|52.84.162.124|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://arttrk.com/p/ST44R/pdrl.fm/f3efd0/stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3?aid=rss_feed [following]
# --2024-01-20 18:41:49--  https://arttrk.com/p/ST44R/pdrl.fm/f3efd0/stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3?aid=rss_feed
# Resolving arttrk.com (arttrk.com)... 52.44.162.123, 44.209.26.132, 52.21.197.50, ...
# Connecting to arttrk.com (arttrk.com)|52.44.162.123|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://pdrl.fm/f3efd0/stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3?aid=rss_feed [following]
# --2024-01-20 18:41:50--  https://pdrl.fm/f3efd0/stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3?aid=rss_feed
# Resolving pdrl.fm (pdrl.fm)... 172.67.14.52, 104.22.49.214, 104.22.48.214, ...
# Connecting to pdrl.fm (pdrl.fm)|172.67.14.52|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3?aid=rss_feed [following]
# --2024-01-20 18:41:50--  https://stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3?aid=rss_feed
# Resolving stitcher.simplecastaudio.com (stitcher.simplecastaudio.com)... 18.172.170.31, 18.172.170.22, 18.172.170.13, ...
# Connecting to stitcher.simplecastaudio.com (stitcher.simplecastaudio.com)|18.172.170.31|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3/default.mp3_ywr3ahjkcgo_cF9mX3NraXA9dSAg_c175534c118fec8a00bd42dbc2915b06_21760910.mp3?aid=rss_feed&hash_redirect=1&x-total-bytes=21760910&x-ais-classified=unclassified&listeningSessionID=0CD_382_19__14b1248afea6a3a7e49e0b331e5d9a57af429f0f [following]
# --2024-01-20 18:41:50--  https://stitcher.simplecastaudio.com/c945bd13-c7f3-4f22-95b5-4bf98e12b21f/episodes/7c00fc69-1c60-4b87-b4c8-fcde21025ed4/audio/128/default.mp3/default.mp3_ywr3ahjkcgo_cF9mX3NraXA9dSAg_c175534c118fec8a00bd42dbc2915b06_21760910.mp3?aid=rss_feed&hash_redirect=1&x-total-bytes=21760910&x-ais-classified=unclassified&listeningSessionID=0CD_382_19__14b1248afea6a3a7e49e0b331e5d9a57af429f0f
# Reusing existing connection to stitcher.simplecastaudio.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 21760910 (21M) [audio/mpeg]
# Saving to: ‘podcast.mp3’
#
# podcast.mp3         100%[===================>]  20.75M  --.-KB/s    in 0.1s
#
# 2024-01-20 18:41:50 (209 MB/s) - ‘podcast.mp3’ saved [21760910/21760910]

# %%
result = model.transcribe('podcast.mp3',language='english')

# %%
with open('sub.vtt', "w") as txt:
  x=  WriteVTT(result)
  txt = WriteVTT(result)

# %%
with open('sub.vtt', "r") as txt:
 print('\n'.join(txt.readlines()))

# %%
x
result
# Out:
# {'text': ' Conan O\'Brien needs a fan. Wanna talk to Conan? Visit teamcoco.com slash call Conan. Okay, let\'s get started. Please. Yes. Hey. Hi, Tom, welcome to Conan O\'Brien. Hello. He needs a fan, nice sweater. Wow. Thank you. Good job. First of all, Gourley on just being so positive so quickly. Tom, so nice to see you. I see you have your- You too. Your Christmas tree in the background. It looks dark where you are. We\'re in Los Angeles, where are you? I\'m Conan from Dublin, Ireland. Oh, you\'re in Dublin. Look at that fine Irish cable knit fisherman sweater and Christmas tree. I didn\'t live in the light. I just wanna trade places with you. I\'m sorry, Mr. Gourley is making this sound like the home shopping network. Tom here is wearing a fine cable net sweater. It\'s gorgeous. It\'s made of a fine Dublin weave. Sir, tell us, and Tom, what\'s your last name? Lawler. Okay, Tom Lawler, calling from or calling, I guess zooming in, calling, whatever you wanna say. Appearing to us magically from Dublin. I love Dublin. I love the few times I\'ve visited there. I\'ve had a fantastic time. Yeah, you\'ve been a few times. I\'ve been a few times. One of the times I went, I met up with a bunch of other, well, very famous Irish comedians from Ireland who were all hilarious, and we all did a show together at the Ambassador\'s residence in Phoenix Park, and I thought these are the funniest people I\'ve ever met, and then all of us got into a cab to go into Dublin to get a drink, and the cabbie was funnier than all of us, and I thought that\'s Dublin. There\'s just everyone that\'s just super high professional level funny. So no pressure on me then for the rest of this interview. Well done. Well, we can always say later on that you\'re, you know, you\'re going through a depressive period, you know, and so that gets you off the hook. Tom, tell me a little bit about yourself. Well, so I live in Dublin, as you know, and I right now am the co-director of a festival here in Dublin that the city started a number of years ago called Bram Stoker Festival, which is basically a way of us celebrating the life and legacy and work of Bram Stoker, who wrote Dracula. Yep, and so this is interesting to me because I don\'t have to say, I admit, I don\'t know much about Bram Stoker, obviously. His work is very famous, but I don\'t know much about the man himself. Was he Irish? Yeah, he was Irish, and I think part of that, one of the big reasons the festival was started was I guess to kind of reclaim him as an Irish author, right? So everybody knows Joyce and Beckett as Irish authors, but I think a lot of people had kind of assumed or thought that Bram Stoker was British, and the Brits have a long history of claiming Irish people as their own when they become very successful, so it was kind of a way of taking it back and kind of reclaiming him as a Dublin-born Irish writer, yeah. That\'s actually very, I mean, that\'s fascinating to me. You may have heard me say, I\'ve said it many times, because it\'s kind of fascinating slash sad to me, but my people emigrated from Ireland in the late 19th century, and we\'ve been living in central Massachusetts, and I\'m still genetically 100% Irish, which is I think tragic. Tom, will you please reclaim him? Yeah. Wait. And Americans desperately want me to be reclaimed, and they mean taken back to Ireland and kept there. Well, we\'d be delighted to reclaim you and have you at the festival anytime, or in Dublin. I mean, you\'re hugely popular. I feel like lots of the friends or the fans on this podcast are coming from Ireland as well, right? You\'ve got to go there. No, it\'s funny, we do have, I do get recognition from Irish people for the TV show, but also a lot from the podcast, which is very nice. So I\'d love to go back there, and I\'d love to reconnect, because I think it would be lovely. That\'s a word that I hear a lot. Lovely. I\'ve heard that in Ireland, they say, isn\'t that lovely? Also, they say, correct me ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 5.0,
#    'text': " Conan O'Brien needs a fan.",
#    'tokens': [50364, 47691, 422, 6, 47999, 2203, 257, 3429, 13, 50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 1,
#    'seek': 0,
#    'start': 6.12,
#    'end': 7.46,
#    'text': ' Wanna talk to Conan?',
#    'tokens': [50670, 24336, 751, 281, 47691, 30, 50737],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 2,
#    'seek': 0,
#    'start': 7.46,
#    'end': 10.88,
#    'text': ' Visit teamcoco.com slash call Conan.',
#    'tokens': [50737,
#     24548,
#     1469,
#     66,
#     11198,
#     13,
#     1112,
#     17330,
#     818,
#     47691,
#     13,
#     50908],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 3,
#    'seek': 0,
#    'start': 10.88,
#    'end': 12.56,
#    'text': " Okay, let's get started.",
#    'tokens': [50908, 1033, 11, 718, 311, 483, 1409, 13, 50992],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 4,
#    'seek': 0,
#    'start': 14.200000000000001,
#    'end': 15.040000000000001,
#    'text': ' Please.',
#    'tokens': [51074, 2555, 13, 51116],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 5,
#    'seek': 0,
#    'start': 15.040000000000001,
#    'end': 15.860000000000001,
#    'text': ' Yes.',
#    'tokens': [51116, 1079, 13, 51157],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 6,
#    'seek': 0,
#    'start': 15.860000000000001,
#    'end': 16.7,
#    'text': ' Hey.',
#    'tokens': [51157, 1911, 13, 51199],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 7,
#    'seek': 0,
#    'start': 16.7,
#    'end': 17.54,
#    'text': " Hi, Tom, welcome to Conan O'Brien.",
#    'tokens': [51199,
#     2421,
#     11,
#     5041,
#     11,
#     2928,
#     281,
#     47691,
#     422,
#     6,
#     47999,
#     13,
#     51241],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 8,
#    'seek': 0,
#    'start': 17.54,
#    'end': 18.36,
#    'text': ' Hello.',
#    'tokens': [51241, 2425, 13, 51282],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 9,
#    'seek': 0,
#    'start': 18.36,
#    'end': 19.56,
#    'text': ' He needs a fan, nice sweater.',
#    'tokens': [51282, 634, 2203, 257, 3429, 11, 1481, 26550, 13, 51342],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 10,
#    'seek': 0,
#    'start': 19.56,
#    'end': 21.1,
#    'text': ' Wow. Thank you.',
#    'tokens': [51342, 3153, 13, 1044, 291, 13, 51419],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 11,
#    'seek': 0,
#    'start': 21.1,
#    'end': 22.22,
#    'text': ' Good job.',
#    'tokens': [51419, 2205, 1691, 13, 51475],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 12,
#    'seek': 0,
#    'start': 22.22,
#    'end': 26.44,
#    'text': ' First of all, Gourley on just being so positive so quickly.',
#    'tokens': [51475,
#     2386,
#     295,
#     439,
#     11,
#     460,
#     396,
#     3420,
#     322,
#     445,
#     885,
#     370,
#     3353,
#     370,
#     2661,
#     13,
#     51686],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 13,
#    'seek': 0,
#    'start': 26.44,
#    'end': 29.2,
#    'text': ' Tom, so nice to see you.',
#    'tokens': [51686, 5041, 11, 370, 1481, 281, 536, 291, 13, 51824],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 14,
#    'seek': 2920,
#    'start': 29.2,
#    'end': 30.04,
#    'text': ' I see you have your-',
#    'tokens': [50364, 286, 536, 291, 362, 428, 12, 50406],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 15,
#    'seek': 2920,
#    'start': 30.04,
#    'end': 30.88,
#    'text': ' You too.',
#    'tokens': [50406, 509, 886, 13, 50448],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 16,
#    'seek': 2920,
#    'start': 30.88,
#    'end': 32.28,
#    'text': ' Your Christmas tree in the background.',
#    'tokens': [50448, 2260, 5272, 4230, 294, 264, 3678, 13, 50518],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 17,
#    'seek': 2920,
#    'start': 32.28,
#    'end': 34.04,
#    'text': ' It looks dark where you are.',
#    'tokens': [50518, 467, 1542, 2877, 689, 291, 366, 13, 50606],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 18,
#    'seek': 2920,
#    'start': 34.04,
#    'end': 35.76,
#    'text': " We're in Los Angeles, where are you?",
#    'tokens': [50606, 492, 434, 294, 7632, 12292, 11, 689, 366, 291, 30, 50692],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 19,
#    'seek': 2920,
#    'start': 35.76,
#    'end': 37.64,
#    'text': " I'm Conan from Dublin, Ireland.",
#    'tokens': [50692, 286, 478, 47691, 490, 42323, 11, 15880, 13, 50786],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 20,
#    'seek': 2920,
#    'start': 37.64,
#    'end': 39.24,
#    'text': " Oh, you're in Dublin.",
#    'tokens': [50786, 876, 11, 291, 434, 294, 42323, 13, 50866],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 21,
#    'seek': 2920,
#    'start': 39.24,
#    'end': 41.32,
#    'text': ' Look at that fine Irish cable knit',
#    'tokens': [50866, 2053, 412, 300, 2489, 16801, 8220, 15594, 50970],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 22,
#    'seek': 2920,
#    'start': 41.32,
#    'end': 43.32,
#    'text': ' fisherman sweater and Christmas tree.',
#    'tokens': [50970, 48657, 26550, 293, 5272, 4230, 13, 51070],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 23,
#    'seek': 2920,
#    'start': 43.32,
#    'end': 44.8,
#    'text': " I didn't live in the light.",
#    'tokens': [51070, 286, 994, 380, 1621, 294, 264, 1442, 13, 51144],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 24,
#    'seek': 2920,
#    'start': 44.8,
#    'end': 46.0,
#    'text': ' I just wanna trade places with you.',
#    'tokens': [51144, 286, 445, 1948, 4923, 3190, 365, 291, 13, 51204],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 25,
#    'seek': 2920,
#    'start': 46.0,
#    'end': 48.4,
#    'text': " I'm sorry, Mr. Gourley is making this sound",
#    'tokens': [51204,
#     286,
#     478,
#     2597,
#     11,
#     2221,
#     13,
#     460,
#     396,
#     3420,
#     307,
#     1455,
#     341,
#     1626,
#     51324],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 26,
#    'seek': 2920,
#    'start': 48.4,
#    'end': 50.0,
#    'text': ' like the home shopping network.',
#    'tokens': [51324, 411, 264, 1280, 8688, 3209, 13, 51404],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 27,
#    'seek': 2920,
#    'start': 50.0,
#    'end': 53.760000000000005,
#    'text': ' Tom here is wearing a fine cable net sweater.',
#    'tokens': [51404,
#     5041,
#     510,
#     307,
#     4769,
#     257,
#     2489,
#     8220,
#     2533,
#     26550,
#     13,
#     51592],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 28,
#    'seek': 2920,
#    'start': 53.760000000000005,
#    'end': 54.6,
#    'text': " It's gorgeous.",
#    'tokens': [51592, 467, 311, 12291, 13, 51634],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 29,
#    'seek': 2920,
#    'start': 54.6,
#    'end': 57.8,
#    'text': " It's made of a fine Dublin weave.",
#    'tokens': [51634, 467, 311, 1027, 295, 257, 2489, 42323, 29145, 13, 51794],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 30,
#    'seek': 5780,
#    'start': 57.8,
#    'end': 60.519999999999996,
#    'text': " Sir, tell us, and Tom, what's your last name?",
#    'tokens': [50364,
#     6144,
#     11,
#     980,
#     505,
#     11,
#     293,
#     5041,
#     11,
#     437,
#     311,
#     428,
#     1036,
#     1315,
#     30,
#     50500],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 31,
#    'seek': 5780,
#    'start': 60.519999999999996,
#    'end': 61.36,
#    'text': ' Lawler.',
#    'tokens': [50500, 7744, 1918, 13, 50542],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 32,
#    'seek': 5780,
#    'start': 61.36,
#    'end': 64.8,
#    'text': ' Okay, Tom Lawler, calling from or calling,',
#    'tokens': [50542,
#     1033,
#     11,
#     5041,
#     7744,
#     1918,
#     11,
#     5141,
#     490,
#     420,
#     5141,
#     11,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 33,
#    'seek': 5780,
#    'start': 64.8,
#    'end': 67.96,
#    'text': ' I guess zooming in, calling, whatever you wanna say.',
#    'tokens': [50714,
#     286,
#     2041,
#     48226,
#     294,
#     11,
#     5141,
#     11,
#     2035,
#     291,
#     1948,
#     584,
#     13,
#     50872],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 34,
#    'seek': 5780,
#    'start': 67.96,
#    'end': 72.28,
#    'text': ' Appearing to us magically from Dublin.',
#    'tokens': [50872, 41322, 1921, 281, 505, 39763, 490, 42323, 13, 51088],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 35,
#    'seek': 5780,
#    'start': 72.28,
#    'end': 73.28,
#    'text': ' I love Dublin.',
#    'tokens': [51088, 286, 959, 42323, 13, 51138],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 36,
#    'seek': 5780,
#    'start': 73.28,
#    'end': 75.4,
#    'text': " I love the few times I've visited there.",
#    'tokens': [51138,
#     286,
#     959,
#     264,
#     1326,
#     1413,
#     286,
#     600,
#     11220,
#     456,
#     13,
#     51244],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 37,
#    'seek': 5780,
#    'start': 75.4,
#    'end': 77.2,
#    'text': " I've had a fantastic time.",
#    'tokens': [51244, 286, 600, 632, 257, 5456, 565, 13, 51334],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 38,
#    'seek': 5780,
#    'start': 77.2,
#    'end': 78.52,
#    'text': " Yeah, you've been a few times.",
#    'tokens': [51334, 865, 11, 291, 600, 668, 257, 1326, 1413, 13, 51400],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 39,
#    'seek': 5780,
#    'start': 78.52,
#    'end': 80.0,
#    'text': " I've been a few times.",
#    'tokens': [51400, 286, 600, 668, 257, 1326, 1413, 13, 51474],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 40,
#    'seek': 5780,
#    'start': 80.0,
#    'end': 84.36,
#    'text': ' One of the times I went, I met up with a bunch of other,',
#    'tokens': [51474,
#     1485,
#     295,
#     264,
#     1413,
#     286,
#     1437,
#     11,
#     286,
#     1131,
#     493,
#     365,
#     257,
#     3840,
#     295,
#     661,
#     11,
#     51692],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 41,
#    'seek': 8436,
#    'start': 84.36,
#    'end': 88.96,
#    'text': ' well, very famous Irish comedians from Ireland',
#    'tokens': [50364,
#     731,
#     11,
#     588,
#     4618,
#     16801,
#     18418,
#     2567,
#     490,
#     15880,
#     50594],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 42,
#    'seek': 8436,
#    'start': 88.96,
#    'end': 92.92,
#    'text': ' who were all hilarious, and we all did a show together',
#    'tokens': [50594,
#     567,
#     645,
#     439,
#     19796,
#     11,
#     293,
#     321,
#     439,
#     630,
#     257,
#     855,
#     1214,
#     50792],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 43,
#    'seek': 8436,
#    'start': 92.92,
#    'end': 95.88,
#    'text': " at the Ambassador's residence in Phoenix Park,",
#    'tokens': [50792, 412, 264, 28506, 311, 19607, 294, 18383, 4964, 11, 50940],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 44,
#    'seek': 8436,
#    'start': 95.88,
#    'end': 97.8,
#    'text': " and I thought these are the funniest people I've ever met,",
#    'tokens': [50940,
#     293,
#     286,
#     1194,
#     613,
#     366,
#     264,
#     42681,
#     561,
#     286,
#     600,
#     1562,
#     1131,
#     11,
#     51036],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 45,
#    'seek': 8436,
#    'start': 97.8,
#    'end': 99.92,
#    'text': ' and then all of us got into a cab',
#    'tokens': [51036, 293, 550, 439, 295, 505, 658, 666, 257, 5487, 51142],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 46,
#    'seek': 8436,
#    'start': 99.92,
#    'end': 102.2,
#    'text': ' to go into Dublin to get a drink,',
#    'tokens': [51142, 281, 352, 666, 42323, 281, 483, 257, 2822, 11, 51256],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 47,
#    'seek': 8436,
#    'start': 102.2,
#    'end': 104.4,
#    'text': ' and the cabbie was funnier than all of us,',
#    'tokens': [51256,
#     293,
#     264,
#     5487,
#     7392,
#     390,
#     1019,
#     19165,
#     813,
#     439,
#     295,
#     505,
#     11,
#     51366],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 48,
#    'seek': 8436,
#    'start': 104.4,
#    'end': 107.36,
#    'text': " and I thought that's Dublin.",
#    'tokens': [51366, 293, 286, 1194, 300, 311, 42323, 13, 51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 49,
#    'seek': 8436,
#    'start': 107.36,
#    'end': 110.24,
#    'text': " There's just everyone that's just super high",
#    'tokens': [51514, 821, 311, 445, 1518, 300, 311, 445, 1687, 1090, 51658],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 50,
#    'seek': 8436,
#    'start': 110.24,
#    'end': 111.96000000000001,
#    'text': ' professional level funny.',
#    'tokens': [51658, 4843, 1496, 4074, 13, 51744],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 51,
#    'seek': 11196,
#    'start': 111.96,
#    'end': 115.91999999999999,
#    'text': ' So no pressure on me then for the rest of this interview.',
#    'tokens': [50364,
#     407,
#     572,
#     3321,
#     322,
#     385,
#     550,
#     337,
#     264,
#     1472,
#     295,
#     341,
#     4049,
#     13,
#     50562],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 52,
#    'seek': 11196,
#    'start': 115.91999999999999,
#    'end': 116.75999999999999,
#    'text': ' Well done.',
#    'tokens': [50562, 1042, 1096, 13, 50604],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 53,
#    'seek': 11196,
#    'start': 119.03999999999999,
#    'end': 120.91999999999999,
#    'text': " Well, we can always say later on that you're,",
#    'tokens': [50718,
#     1042,
#     11,
#     321,
#     393,
#     1009,
#     584,
#     1780,
#     322,
#     300,
#     291,
#     434,
#     11,
#     50812],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 54,
#    'seek': 11196,
#    'start': 120.91999999999999,
#    'end': 122.75999999999999,
#    'text': " you know, you're going through a depressive period,",
#    'tokens': [50812,
#     291,
#     458,
#     11,
#     291,
#     434,
#     516,
#     807,
#     257,
#     1367,
#     22733,
#     2896,
#     11,
#     50904],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 55,
#    'seek': 11196,
#    'start': 122.75999999999999,
#    'end': 125.32,
#    'text': ' you know, and so that gets you off the hook.',
#    'tokens': [50904,
#     291,
#     458,
#     11,
#     293,
#     370,
#     300,
#     2170,
#     291,
#     766,
#     264,
#     6328,
#     13,
#     51032],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 56,
#    'seek': 11196,
#    'start': 125.32,
#    'end': 127.44,
#    'text': ' Tom, tell me a little bit about yourself.',
#    'tokens': [51032, 5041, 11, 980, 385, 257, 707, 857, 466, 1803, 13, 51138],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 57,
#    'seek': 11196,
#    'start': 128.79999999999998,
#    'end': 131.4,
#    'text': ' Well, so I live in Dublin, as you know,',
#    'tokens': [51206,
#     1042,
#     11,
#     370,
#     286,
#     1621,
#     294,
#     42323,
#     11,
#     382,
#     291,
#     458,
#     11,
#     51336],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 58,
#    'seek': 11196,
#    'start': 131.4,
#    'end': 134.64,
#    'text': ' and I right now am the co-director of a festival',
#    'tokens': [51336,
#     293,
#     286,
#     558,
#     586,
#     669,
#     264,
#     598,
#     12,
#     18267,
#     1672,
#     295,
#     257,
#     12091,
#     51498],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 59,
#    'seek': 11196,
#    'start': 134.64,
#    'end': 137.0,
#    'text': ' here in Dublin that the city started a number of years ago',
#    'tokens': [51498,
#     510,
#     294,
#     42323,
#     300,
#     264,
#     2307,
#     1409,
#     257,
#     1230,
#     295,
#     924,
#     2057,
#     51616],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 60,
#    'seek': 11196,
#    'start': 137.0,
#    'end': 138.64,
#    'text': ' called Bram Stoker Festival,',
#    'tokens': [51616, 1219, 1603, 335, 745, 16722, 16512, 11, 51698],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 61,
#    'seek': 11196,
#    'start': 138.64,
#    'end': 141.64,
#    'text': ' which is basically a way of us celebrating',
#    'tokens': [51698, 597, 307, 1936, 257, 636, 295, 505, 15252, 51848],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 62,
#    'seek': 14164,
#    'start': 141.64,
#    'end': 143.67999999999998,
#    'text': ' the life and legacy and work of Bram Stoker,',
#    'tokens': [50364,
#     264,
#     993,
#     293,
#     11711,
#     293,
#     589,
#     295,
#     1603,
#     335,
#     745,
#     16722,
#     11,
#     50466],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 63,
#    'seek': 14164,
#    'start': 143.67999999999998,
#    'end': 144.79999999999998,
#    'text': ' who wrote Dracula.',
#    'tokens': [50466, 567, 4114, 48950, 13, 50522],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 64,
#    'seek': 14164,
#    'start': 144.79999999999998,
#    'end': 147.11999999999998,
#    'text': ' Yep, and so this is interesting to me',
#    'tokens': [50522, 7010, 11, 293, 370, 341, 307, 1880, 281, 385, 50638],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 65,
#    'seek': 14164,
#    'start': 147.11999999999998,
#    'end': 148.83999999999997,
#    'text': " because I don't have to say, I admit,",
#    'tokens': [50638,
#     570,
#     286,
#     500,
#     380,
#     362,
#     281,
#     584,
#     11,
#     286,
#     9796,
#     11,
#     50724],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 66,
#    'seek': 14164,
#    'start': 148.83999999999997,
#    'end': 153.55999999999997,
#    'text': " I don't know much about Bram Stoker, obviously.",
#    'tokens': [50724,
#     286,
#     500,
#     380,
#     458,
#     709,
#     466,
#     1603,
#     335,
#     745,
#     16722,
#     11,
#     2745,
#     13,
#     50960],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 67,
#    'seek': 14164,
#    'start': 153.55999999999997,
#    'end': 154.67999999999998,
#    'text': ' His work is very famous,',
#    'tokens': [50960, 2812, 589, 307, 588, 4618, 11, 51016],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 68,
#    'seek': 14164,
#    'start': 154.67999999999998,
#    'end': 158.48,
#    'text': " but I don't know much about the man himself.",
#    'tokens': [51016,
#     457,
#     286,
#     500,
#     380,
#     458,
#     709,
#     466,
#     264,
#     587,
#     3647,
#     13,
#     51206],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 69,
#    'seek': 14164,
#    'start': 158.48,
#    'end': 159.6,
#    'text': ' Was he Irish?',
#    'tokens': [51206, 3027, 415, 16801, 30, 51262],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 70,
#    'seek': 14164,
#    'start': 160.88,
#    'end': 162.92,
#    'text': ' Yeah, he was Irish, and I think part of that,',
#    'tokens': [51326,
#     865,
#     11,
#     415,
#     390,
#     16801,
#     11,
#     293,
#     286,
#     519,
#     644,
#     295,
#     300,
#     11,
#     51428],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 71,
#    'seek': 14164,
#    'start': 162.92,
#    'end': 165.11999999999998,
#    'text': ' one of the big reasons the festival was started',
#    'tokens': [51428, 472, 295, 264, 955, 4112, 264, 12091, 390, 1409, 51538],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 72,
#    'seek': 14164,
#    'start': 165.11999999999998,
#    'end': 168.92,
#    'text': ' was I guess to kind of reclaim him as an Irish author, right?',
#    'tokens': [51538,
#     390,
#     286,
#     2041,
#     281,
#     733,
#     295,
#     40074,
#     796,
#     382,
#     364,
#     16801,
#     3793,
#     11,
#     558,
#     30,
#     51728],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 73,
#    'seek': 14164,
#    'start': 168.92,
#    'end': 171.6,
#    'text': ' So everybody knows Joyce and Beckett as Irish authors,',
#    'tokens': [51728,
#     407,
#     2201,
#     3255,
#     40044,
#     293,
#     19184,
#     3093,
#     382,
#     16801,
#     16552,
#     11,
#     51862],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 74,
#    'seek': 17160,
#    'start': 172.6,
#    'end': 173.76,
#    'text': ' but I think a lot of people had kind of assumed',
#    'tokens': [50414,
#     457,
#     286,
#     519,
#     257,
#     688,
#     295,
#     561,
#     632,
#     733,
#     295,
#     15895,
#     50472],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 75,
#    'seek': 17160,
#    'start': 173.76,
#    'end': 175.56,
#    'text': ' or thought that Bram Stoker was British,',
#    'tokens': [50472,
#     420,
#     1194,
#     300,
#     1603,
#     335,
#     745,
#     16722,
#     390,
#     6221,
#     11,
#     50562],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 76,
#    'seek': 17160,
#    'start': 175.56,
#    'end': 179.48,
#    'text': ' and the Brits have a long history of claiming Irish people',
#    'tokens': [50562,
#     293,
#     264,
#     1603,
#     1208,
#     362,
#     257,
#     938,
#     2503,
#     295,
#     19232,
#     16801,
#     561,
#     50758],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 77,
#    'seek': 17160,
#    'start': 179.48,
#    'end': 181.2,
#    'text': ' as their own when they become very successful,',
#    'tokens': [50758, 382, 641, 1065, 562, 436, 1813, 588, 4406, 11, 50844],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 78,
#    'seek': 17160,
#    'start': 181.2,
#    'end': 183.16,
#    'text': ' so it was kind of a way of taking it back',
#    'tokens': [50844,
#     370,
#     309,
#     390,
#     733,
#     295,
#     257,
#     636,
#     295,
#     1940,
#     309,
#     646,
#     50942],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 79,
#    'seek': 17160,
#    'start': 183.16,
#    'end': 188.16,
#    'text': ' and kind of reclaiming him as a Dublin-born Irish writer, yeah.',
#    'tokens': [50942,
#     293,
#     733,
#     295,
#     40074,
#     278,
#     796,
#     382,
#     257,
#     42323,
#     12,
#     10324,
#     16801,
#     9936,
#     11,
#     1338,
#     13,
#     51192],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 80,
#    'seek': 17160,
#    'start': 188.35999999999999,
#    'end': 192.04,
#    'text': " That's actually very, I mean, that's fascinating to me.",
#    'tokens': [51202,
#     663,
#     311,
#     767,
#     588,
#     11,
#     286,
#     914,
#     11,
#     300,
#     311,
#     10343,
#     281,
#     385,
#     13,
#     51386],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 81,
#    'seek': 17160,
#    'start': 192.04,
#    'end': 194.92,
#    'text': " You may have heard me say, I've said it many times,",
#    'tokens': [51386,
#     509,
#     815,
#     362,
#     2198,
#     385,
#     584,
#     11,
#     286,
#     600,
#     848,
#     309,
#     867,
#     1413,
#     11,
#     51530],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 82,
#    'seek': 17160,
#    'start': 194.92,
#    'end': 198.16,
#    'text': " because it's kind of fascinating slash sad to me,",
#    'tokens': [51530,
#     570,
#     309,
#     311,
#     733,
#     295,
#     10343,
#     17330,
#     4227,
#     281,
#     385,
#     11,
#     51692],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 83,
#    'seek': 19816,
#    'start': 198.16,
#    'end': 202.56,
#    'text': ' but my people emigrated from Ireland',
#    'tokens': [50364, 457, 452, 561, 846, 328, 5468, 490, 15880, 50584],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 84,
#    'seek': 19816,
#    'start': 202.56,
#    'end': 203.72,
#    'text': ' in the late 19th century,',
#    'tokens': [50584, 294, 264, 3469, 1294, 392, 4901, 11, 50642],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 85,
#    'seek': 19816,
#    'start': 203.72,
#    'end': 205.68,
#    'text': " and we've been living in central Massachusetts,",
#    'tokens': [50642, 293, 321, 600, 668, 2647, 294, 5777, 19979, 11, 50740],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 86,
#    'seek': 19816,
#    'start': 205.68,
#    'end': 208.4,
#    'text': " and I'm still genetically 100% Irish,",
#    'tokens': [50740, 293, 286, 478, 920, 37582, 2319, 4, 16801, 11, 50876],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 87,
#    'seek': 19816,
#    'start': 209.56,
#    'end': 211.32,
#    'text': ' which is I think tragic.',
#    'tokens': [50934, 597, 307, 286, 519, 20385, 13, 51022],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 88,
#    'seek': 19816,
#    'start': 211.32,
#    'end': 212.92,
#    'text': ' Tom, will you please reclaim him?',
#    'tokens': [51022, 5041, 11, 486, 291, 1767, 40074, 796, 30, 51102],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 89,
#    'seek': 19816,
#    'start': 212.92,
#    'end': 213.76,
#    'text': ' Yeah.',
#    'tokens': [51102, 865, 13, 51144],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 90,
#    'seek': 19816,
#    'start': 213.76,
#    'end': 214.57999999999998,
#    'text': ' Wait.',
#    'tokens': [51144, 3802, 13, 51185],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 91,
#    'seek': 19816,
#    'start': 214.57999999999998,
#    'end': 219.57999999999998,
#    'text': ' And Americans desperately want me to be reclaimed,',
#    'tokens': [51185,
#     400,
#     6280,
#     23726,
#     528,
#     385,
#     281,
#     312,
#     850,
#     22642,
#     11,
#     51435],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 92,
#    'seek': 19816,
#    'start': 220.04,
#    'end': 223.07999999999998,
#    'text': ' and they mean taken back to Ireland and kept there.',
#    'tokens': [51458,
#     293,
#     436,
#     914,
#     2726,
#     646,
#     281,
#     15880,
#     293,
#     4305,
#     456,
#     13,
#     51610],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 93,
#    'seek': 19816,
#    'start': 223.07999999999998,
#    'end': 224.92,
#    'text': " Well, we'd be delighted to reclaim you",
#    'tokens': [51610, 1042, 11, 321, 1116, 312, 18783, 281, 40074, 291, 51702],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 94,
#    'seek': 19816,
#    'start': 224.92,
#    'end': 226.88,
#    'text': ' and have you at the festival anytime, or in Dublin.',
#    'tokens': [51702,
#     293,
#     362,
#     291,
#     412,
#     264,
#     12091,
#     13038,
#     11,
#     420,
#     294,
#     42323,
#     13,
#     51800],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 95,
#    'seek': 22688,
#    'start': 226.88,
#    'end': 228.24,
#    'text': " I mean, you're hugely popular.",
#    'tokens': [50364, 286, 914, 11, 291, 434, 27417, 3743, 13, 50432],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 96,
#    'seek': 22688,
#    'start': 228.24,
#    'end': 230.35999999999999,
#    'text': ' I feel like lots of the friends or the fans',
#    'tokens': [50432,
#     286,
#     841,
#     411,
#     3195,
#     295,
#     264,
#     1855,
#     420,
#     264,
#     4499,
#     50538],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 97,
#    'seek': 22688,
#    'start': 230.35999999999999,
#    'end': 232.16,
#    'text': ' on this podcast are coming from Ireland as well, right?',
#    'tokens': [50538,
#     322,
#     341,
#     7367,
#     366,
#     1348,
#     490,
#     15880,
#     382,
#     731,
#     11,
#     558,
#     30,
#     50628],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 98,
#    'seek': 22688,
#    'start': 232.16,
#    'end': 233.0,
#    'text': " You've got to go there.",
#    'tokens': [50628, 509, 600, 658, 281, 352, 456, 13, 50670],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 99,
#    'seek': 22688,
#    'start': 233.0,
#    'end': 234.76,
#    'text': " No, it's funny, we do have,",
#    'tokens': [50670, 883, 11, 309, 311, 4074, 11, 321, 360, 362, 11, 50758],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 100,
#    'seek': 22688,
#    'start': 234.76,
#    'end': 239.76,
#    'text': ' I do get recognition from Irish people for the TV show,',
#    'tokens': [50758,
#     286,
#     360,
#     483,
#     11150,
#     490,
#     16801,
#     561,
#     337,
#     264,
#     3558,
#     855,
#     11,
#     51008],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 101,
#    'seek': 22688,
#    'start': 241.04,
#    'end': 245.0,
#    'text': ' but also a lot from the podcast, which is very nice.',
#    'tokens': [51072,
#     457,
#     611,
#     257,
#     688,
#     490,
#     264,
#     7367,
#     11,
#     597,
#     307,
#     588,
#     1481,
#     13,
#     51270],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 102,
#    'seek': 22688,
#    'start': 245.0,
#    'end': 247.48,
#    'text': " So I'd love to go back there,",
#    'tokens': [51270, 407, 286, 1116, 959, 281, 352, 646, 456, 11, 51394],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 103,
#    'seek': 22688,
#    'start': 247.48,
#    'end': 250.6,
#    'text': " and I'd love to reconnect,",
#    'tokens': [51394, 293, 286, 1116, 959, 281, 30095, 11, 51550],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 104,
#    'seek': 22688,
#    'start': 250.6,
#    'end': 253.07999999999998,
#    'text': ' because I think it would be lovely.',
#    'tokens': [51550, 570, 286, 519, 309, 576, 312, 7496, 13, 51674],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 105,
#    'seek': 22688,
#    'start': 253.07999999999998,
#    'end': 255.14,
#    'text': " That's a word that I hear a lot.",
#    'tokens': [51674, 663, 311, 257, 1349, 300, 286, 1568, 257, 688, 13, 51777],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 106,
#    'seek': 22688,
#    'start': 255.14,
#    'end': 255.98,
#    'text': ' Lovely.',
#    'tokens': [51777, 33925, 13, 51819],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 107,
#    'seek': 25598,
#    'start': 256.38,
#    'end': 257.86,
#    'text': " I've heard that in Ireland, they say,",
#    'tokens': [50384, 286, 600, 2198, 300, 294, 15880, 11, 436, 584, 11, 50458],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 108,
#    'seek': 25598,
#    'start': 257.86,
#    'end': 259.26,
#    'text': " isn't that lovely?",
#    'tokens': [50458, 1943, 380, 300, 7496, 30, 50528],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 109,
#    'seek': 25598,
#    'start': 259.26,
#    'end': 262.42,
#    'text': " Also, they say, correct me if I'm wrong, Tom,",
#    'tokens': [50528,
#     2743,
#     11,
#     436,
#     584,
#     11,
#     3006,
#     385,
#     498,
#     286,
#     478,
#     2085,
#     11,
#     5041,
#     11,
#     50686],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 110,
#    'seek': 25598,
#    'start': 262.42,
#    'end': 264.58,
#    'text': ' in America, people say um.',
#    'tokens': [50686, 294, 3374, 11, 561, 584, 1105, 13, 50794],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 111,
#    'seek': 25598,
#    'start': 264.58,
#    'end': 268.82,
#    'text': ' So if you ask me a question, I say, um, yeah.',
#    'tokens': [50794,
#     407,
#     498,
#     291,
#     1029,
#     385,
#     257,
#     1168,
#     11,
#     286,
#     584,
#     11,
#     1105,
#     11,
#     1338,
#     13,
#     51006],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 112,
#    'seek': 25598,
#    'start': 268.82,
#    'end': 270.62,
#    'text': ' I live near the Volkswagen dealership,',
#    'tokens': [51006, 286, 1621, 2651, 264, 39856, 25955, 1210, 11, 51096],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 113,
#    'seek': 25598,
#    'start': 270.62,
#    'end': 272.02,
#    'text': ' but about two blocks away.',
#    'tokens': [51096, 457, 466, 732, 8474, 1314, 13, 51166],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 114,
#    'seek': 25598,
#    'start': 273.26,
#    'end': 275.86,
#    'text': " The people I've met in Dublin say M, E, M.",
#    'tokens': [51228,
#     440,
#     561,
#     286,
#     600,
#     1131,
#     294,
#     42323,
#     584,
#     376,
#     11,
#     462,
#     11,
#     376,
#     13,
#     51358],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 115,
#    'seek': 25598,
#    'start': 275.86,
#    'end': 276.94,
#    'text': ' Yeah, Gretan Norton.',
#    'tokens': [51358, 865, 11, 460, 1505, 282, 426, 36184, 13, 51412],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 116,
#    'seek': 25598,
#    'start': 276.94,
#    'end': 278.18,
#    'text': ' Yeah, have you noticed that?',
#    'tokens': [51412, 865, 11, 362, 291, 5694, 300, 30, 51474],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 117,
#    'seek': 25598,
#    'start': 278.18,
#    'end': 279.98,
#    'text': " Yeah, actually, yeah, it's funny you say that,",
#    'tokens': [51474,
#     865,
#     11,
#     767,
#     11,
#     1338,
#     11,
#     309,
#     311,
#     4074,
#     291,
#     584,
#     300,
#     11,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 118,
#    'seek': 25598,
#    'start': 279.98,
#    'end': 281.09999999999997,
#    'text': ' because um.',
#    'tokens': [51564, 570, 1105, 13, 51620],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
# ...
#    'no_speech_prob': 0.00032502529211342335},
#   {'id': 580,
#    'seek': 123128,
#    'start': 1257.24,
#    'end': 1259.6,
#    'text': " Okay, now you're just poking fun and that's ridiculous.",
#    'tokens': [51662,
#     1033,
#     11,
#     586,
#     291,
#     434,
#     445,
#     42684,
#     1019,
#     293,
#     300,
#     311,
#     11083,
#     13,
#     51780],
#    'temperature': 0.0,
#    'avg_logprob': -0.24373144732263988,
#    'compression_ratio': 1.6941580756013745,
#    'no_speech_prob': 0.00032502529211342335},
#   {'id': 581,
#    'seek': 125960,
#    'start': 1259.6,
#    'end': 1261.3999999999999,
#    'text': " Well, I'm really happy with myself.",
#    'tokens': [50364, 1042, 11, 286, 478, 534, 2055, 365, 2059, 13, 50454],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 582,
#    'seek': 125960,
#    'start': 1261.3999999999999,
#    'end': 1263.28,
#    'text': ' Tom, thank you.',
#    'tokens': [50454, 5041, 11, 1309, 291, 13, 50548],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 583,
#    'seek': 125960,
#    'start': 1263.28,
#    'end': 1264.32,
#    'text': ' Thank you for reaching out.',
#    'tokens': [50548, 1044, 291, 337, 9906, 484, 13, 50600],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 584,
#    'seek': 125960,
#    'start': 1264.32,
#    'end': 1265.1599999999999,
#    'text': ' Thank you.',
#    'tokens': [50600, 1044, 291, 13, 50642],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 585,
#    'seek': 125960,
#    'start': 1265.1599999999999,
#    'end': 1267.24,
#    'text': ' Speaking to us, I will take it to heart',
#    'tokens': [50642,
#     13069,
#     281,
#     505,
#     11,
#     286,
#     486,
#     747,
#     309,
#     281,
#     1917,
#     50746],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 586,
#    'seek': 125960,
#    'start': 1267.24,
#    'end': 1269.56,
#    'text': ' this whole Bram Stoker controversy.',
#    'tokens': [50746, 341, 1379, 1603, 335, 745, 16722, 22976, 13, 50862],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 587,
#    'seek': 125960,
#    'start': 1269.56,
#    'end': 1273.56,
#    'text': ' I will work in the fact that Bram Stoker is Irish',
#    'tokens': [50862,
#     286,
#     486,
#     589,
#     294,
#     264,
#     1186,
#     300,
#     1603,
#     335,
#     745,
#     16722,
#     307,
#     16801,
#     51062],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 588,
#    'seek': 125960,
#    'start': 1273.56,
#    'end': 1276.48,
#    'text': ' in every conversation that I can in the most awkward way.',
#    'tokens': [51062,
#     294,
#     633,
#     3761,
#     300,
#     286,
#     393,
#     294,
#     264,
#     881,
#     11411,
#     636,
#     13,
#     51208],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 589,
#    'seek': 125960,
#    'start': 1276.48,
#    'end': 1277.32,
#    'text': ' And I will fight this-',
#    'tokens': [51208, 400, 286, 486, 2092, 341, 12, 51250],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 590,
#    'seek': 125960,
#    'start': 1277.32,
#    'end': 1278.52,
#    'text': " Thank you, I'd really appreciate it.",
#    'tokens': [51250, 1044, 291, 11, 286, 1116, 534, 4449, 309, 13, 51310],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 591,
#    'seek': 125960,
#    'start': 1278.52,
#    'end': 1281.24,
#    'text': ' All right, well, happy holidays.',
#    'tokens': [51310, 1057, 558, 11, 731, 11, 2055, 15734, 13, 51446],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 592,
#    'seek': 125960,
#    'start': 1281.24,
#    'end': 1282.08,
#    'text': ' Yeah, you too.',
#    'tokens': [51446, 865, 11, 291, 886, 13, 51488],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 593,
#    'seek': 125960,
#    'start': 1282.08,
#    'end': 1282.9199999999998,
#    'text': ' And thank you so much.',
#    'tokens': [51488, 400, 1309, 291, 370, 709, 13, 51530],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 594,
#    'seek': 125960,
#    'start': 1282.9199999999998,
#    'end': 1283.74,
#    'text': ' Take care.',
#    'tokens': [51530, 3664, 1127, 13, 51571],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 595,
#    'seek': 125960,
#    'start': 1283.74,
#    'end': 1284.58,
#    'text': ' Thank you guys, thanks very much.',
#    'tokens': [51571, 1044, 291, 1074, 11, 3231, 588, 709, 13, 51613],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 596,
#    'seek': 125960,
#    'start': 1284.58,
#    'end': 1285.3999999999999,
#    'text': ' Thank you. Bye-bye.',
#    'tokens': [51613, 1044, 291, 13, 4621, 12, 6650, 13, 51654],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 597,
#    'seek': 125960,
#    'start': 1285.3999999999999,
#    'end': 1286.24,
#    'text': ' Bye-bye.',
#    'tokens': [51654, 4621, 12, 6650, 13, 51696],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 598,
#    'seek': 128624,
#    'start': 1286.92,
#    'end': 1288.8,
#    'text': " Conan O'Brien needs a friend.",
#    'tokens': [50398, 47691, 422, 6, 47999, 2203, 257, 1277, 13, 50492],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 599,
#    'seek': 128624,
#    'start': 1288.8,
#    'end': 1292.24,
#    'text': " With Conan O'Brien, Sonam Ovsessian, and Matt Gourley.",
#    'tokens': [50492,
#     2022,
#     47691,
#     422,
#     6,
#     47999,
#     11,
#     5185,
#     335,
#     422,
#     36959,
#     442,
#     952,
#     11,
#     293,
#     7397,
#     460,
#     396,
#     3420,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 600,
#    'seek': 128624,
#    'start': 1292.24,
#    'end': 1294.0,
#    'text': ' Produced by me, Matt Gourley.',
#    'tokens': [50664,
#     11793,
#     1232,
#     538,
#     385,
#     11,
#     7397,
#     460,
#     396,
#     3420,
#     13,
#     50752],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 601,
#    'seek': 128624,
#    'start': 1294.0,
#    'end': 1296.6,
#    'text': ' Executive produced by Adam Sachs, Nick Leal,',
#    'tokens': [50752,
#     20658,
#     7126,
#     538,
#     7938,
#     25626,
#     82,
#     11,
#     9449,
#     1456,
#     304,
#     11,
#     50882],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 602,
#    'seek': 128624,
#    'start': 1296.6,
#    'end': 1298.36,
#    'text': ' and Jeff Ross at Team Coco,',
#    'tokens': [50882, 293, 7506, 16140, 412, 7606, 29787, 11, 50970],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 603,
#    'seek': 128624,
#    'start': 1298.36,
#    'end': 1301.52,
#    'text': ' and Colin Anderson and Cody Fisher at Earwolf.',
#    'tokens': [50970,
#     293,
#     29253,
#     18768,
#     293,
#     34524,
#     26676,
#     412,
#     3929,
#     34763,
#     13,
#     51128],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 604,
#    'seek': 128624,
#    'start': 1301.52,
#    'end': 1303.48,
#    'text': ' Theme song by The White Stripes.',
#    'tokens': [51128, 42428, 2153, 538, 440, 5552, 20390, 5190, 13, 51226],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 605,
#    'seek': 128624,
#    'start': 1303.48,
#    'end': 1305.52,
#    'text': ' Incidental music by Jimmy Vivino.',
#    'tokens': [51226, 7779, 47023, 1318, 538, 15709, 28188, 2982, 13, 51328],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 606,
#    'seek': 128624,
#    'start': 1305.52,
#    'end': 1306.52,
#    'text': ' Take it away, Jimmy.',
#    'tokens': [51328, 3664, 309, 1314, 11, 15709, 13, 51378],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 607,
#    'seek': 128624,
#    'start': 1309.32,
#    'end': 1311.36,
#    'text': ' Our supervising producer is Aaron Blair,',
#    'tokens': [51518, 2621, 37971, 3436, 12314, 307, 14018, 42157, 11, 51620],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 608,
#    'seek': 128624,
#    'start': 1311.36,
#    'end': 1314.02,
#    'text': ' and our associate talent producer is Jennifer Samples.',
#    'tokens': [51620,
#     293,
#     527,
#     14644,
#     8301,
#     12314,
#     307,
#     14351,
#     4832,
#     2622,
#     13,
#     51753],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 609,
#    'seek': 131402,
#    'start': 1314.06,
#    'end': 1316.02,
#    'text': ' Engineering by Eduardo Perez.',
#    'tokens': [50366, 16215, 538, 45819, 47317, 13, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 610,
#    'seek': 131402,
#    'start': 1316.02,
#    'end': 1318.54,
#    'text': ' Additional production support by Mars Melnick.',
#    'tokens': [50464, 44272, 4265, 1406, 538, 9692, 7375, 77, 618, 13, 50590],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 611,
#    'seek': 131402,
#    'start': 1318.54,
#    'end': 1322.54,
#    'text': ' Talent booking by Paula Davis, Gina Battista, and Brit Kahn.',
#    'tokens': [50590,
#     44081,
#     34424,
#     538,
#     31663,
#     15658,
#     11,
#     34711,
#     29439,
#     5236,
#     11,
#     293,
#     4760,
#     591,
#     12140,
#     13,
#     50790],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 612,
#    'seek': 131402,
#    'start': 1322.54,
#    'end': 1324.96,
#    'text': ' You can rate and review this show on Apple Podcasts,',
#    'tokens': [50790,
#     509,
#     393,
#     3314,
#     293,
#     3131,
#     341,
#     855,
#     322,
#     6373,
#     29972,
#     82,
#     11,
#     50911],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 613,
#    'seek': 131402,
#    'start': 1324.96,
#    'end': 1327.82,
#    'text': ' and you might find your review read on a future episode.',
#    'tokens': [50911,
#     293,
#     291,
#     1062,
#     915,
#     428,
#     3131,
#     1401,
#     322,
#     257,
#     2027,
#     3500,
#     13,
#     51054],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 614,
#    'seek': 131402,
#    'start': 1327.82,
#    'end': 1329.1399999999999,
#    'text': ' Got a question for Conan?',
#    'tokens': [51054, 5803, 257, 1168, 337, 47691, 30, 51120],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 615,
#    'seek': 131402,
#    'start': 1329.1399999999999,
#    'end': 1333.46,
#    'text': ' Call the Team Coco hotline at 669-587-2847',
#    'tokens': [51120,
#     7807,
#     264,
#     7606,
#     29787,
#     2368,
#     1889,
#     412,
#     21126,
#     24,
#     12,
#     20419,
#     22,
#     12,
#     11205,
#     14060,
#     51336],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 616,
#    'seek': 131402,
#    'start': 1333.46,
#    'end': 1334.5,
#    'text': ' and leave a message.',
#    'tokens': [51336, 293, 1856, 257, 3636, 13, 51388],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 617,
#    'seek': 131402,
#    'start': 1334.5,
#    'end': 1336.74,
#    'text': ' It too could be featured on a future episode.',
#    'tokens': [51388,
#     467,
#     886,
#     727,
#     312,
#     13822,
#     322,
#     257,
#     2027,
#     3500,
#     13,
#     51500],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 618,
#    'seek': 131402,
#    'start': 1336.74,
#    'end': 1337.86,
#    'text': " And if you haven't already,",
#    'tokens': [51500, 400, 498, 291, 2378, 380, 1217, 11, 51556],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 619,
#    'seek': 131402,
#    'start': 1337.86,
#    'end': 1340.1399999999999,
#    'text': " please subscribe to Conan O'Brien Needs a Friend",
#    'tokens': [51556,
#     1767,
#     3022,
#     281,
#     47691,
#     422,
#     6,
#     47999,
#     1734,
#     5147,
#     257,
#     22812,
#     51670],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 620,
#    'seek': 131402,
#    'start': 1340.1399999999999,
#    'end': 1342.62,
#    'text': ' wherever fine podcasts are downloaded.',
#    'tokens': [51670, 8660, 2489, 24045, 366, 21748, 13, 51794],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 621,
#    'seek': 134402,
#    'start': 1344.02,
#    'end': 1347.02,
#    'text': ' This has been a Team Coco production',
#    'tokens': [50364, 639, 575, 668, 257, 7606, 29787, 4265, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.4807692633734809,
#    'compression_ratio': 0.9558823529411765,
#    'no_speech_prob': 0.006484341807663441},
#   {'id': 622,
#    'seek': 134402,
#    'start': 1347.02,
#    'end': 1349.02,
#    'text': ' in association with Earwolf.',
#    'tokens': [50514, 294, 14598, 365, 3929, 34763, 13, 50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.4807692633734809,
#    'compression_ratio': 0.9558823529411765,
#    'no_speech_prob': 0.006484341807663441}],
#  'language': 'english'}

# %%
result
# Out:
# {'text': ' Conan O\'Brien needs a fan. Wanna talk to Conan? Visit teamcoco.com slash call Conan. Okay, let\'s get started. Please. Yes. Hey. Hi, Tom, welcome to Conan O\'Brien. Hello. He needs a fan, nice sweater. Wow. Thank you. Good job. First of all, Gourley on just being so positive so quickly. Tom, so nice to see you. I see you have your- You too. Your Christmas tree in the background. It looks dark where you are. We\'re in Los Angeles, where are you? I\'m Conan from Dublin, Ireland. Oh, you\'re in Dublin. Look at that fine Irish cable knit fisherman sweater and Christmas tree. I didn\'t live in the light. I just wanna trade places with you. I\'m sorry, Mr. Gourley is making this sound like the home shopping network. Tom here is wearing a fine cable net sweater. It\'s gorgeous. It\'s made of a fine Dublin weave. Sir, tell us, and Tom, what\'s your last name? Lawler. Okay, Tom Lawler, calling from or calling, I guess zooming in, calling, whatever you wanna say. Appearing to us magically from Dublin. I love Dublin. I love the few times I\'ve visited there. I\'ve had a fantastic time. Yeah, you\'ve been a few times. I\'ve been a few times. One of the times I went, I met up with a bunch of other, well, very famous Irish comedians from Ireland who were all hilarious, and we all did a show together at the Ambassador\'s residence in Phoenix Park, and I thought these are the funniest people I\'ve ever met, and then all of us got into a cab to go into Dublin to get a drink, and the cabbie was funnier than all of us, and I thought that\'s Dublin. There\'s just everyone that\'s just super high professional level funny. So no pressure on me then for the rest of this interview. Well done. Well, we can always say later on that you\'re, you know, you\'re going through a depressive period, you know, and so that gets you off the hook. Tom, tell me a little bit about yourself. Well, so I live in Dublin, as you know, and I right now am the co-director of a festival here in Dublin that the city started a number of years ago called Bram Stoker Festival, which is basically a way of us celebrating the life and legacy and work of Bram Stoker, who wrote Dracula. Yep, and so this is interesting to me because I don\'t have to say, I admit, I don\'t know much about Bram Stoker, obviously. His work is very famous, but I don\'t know much about the man himself. Was he Irish? Yeah, he was Irish, and I think part of that, one of the big reasons the festival was started was I guess to kind of reclaim him as an Irish author, right? So everybody knows Joyce and Beckett as Irish authors, but I think a lot of people had kind of assumed or thought that Bram Stoker was British, and the Brits have a long history of claiming Irish people as their own when they become very successful, so it was kind of a way of taking it back and kind of reclaiming him as a Dublin-born Irish writer, yeah. That\'s actually very, I mean, that\'s fascinating to me. You may have heard me say, I\'ve said it many times, because it\'s kind of fascinating slash sad to me, but my people emigrated from Ireland in the late 19th century, and we\'ve been living in central Massachusetts, and I\'m still genetically 100% Irish, which is I think tragic. Tom, will you please reclaim him? Yeah. Wait. And Americans desperately want me to be reclaimed, and they mean taken back to Ireland and kept there. Well, we\'d be delighted to reclaim you and have you at the festival anytime, or in Dublin. I mean, you\'re hugely popular. I feel like lots of the friends or the fans on this podcast are coming from Ireland as well, right? You\'ve got to go there. No, it\'s funny, we do have, I do get recognition from Irish people for the TV show, but also a lot from the podcast, which is very nice. So I\'d love to go back there, and I\'d love to reconnect, because I think it would be lovely. That\'s a word that I hear a lot. Lovely. I\'ve heard that in Ireland, they say, isn\'t that lovely? Also, they say, correct me ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 5.0,
#    'text': " Conan O'Brien needs a fan.",
#    'tokens': [50364, 47691, 422, 6, 47999, 2203, 257, 3429, 13, 50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 1,
#    'seek': 0,
#    'start': 6.12,
#    'end': 7.46,
#    'text': ' Wanna talk to Conan?',
#    'tokens': [50670, 24336, 751, 281, 47691, 30, 50737],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 2,
#    'seek': 0,
#    'start': 7.46,
#    'end': 10.88,
#    'text': ' Visit teamcoco.com slash call Conan.',
#    'tokens': [50737,
#     24548,
#     1469,
#     66,
#     11198,
#     13,
#     1112,
#     17330,
#     818,
#     47691,
#     13,
#     50908],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 3,
#    'seek': 0,
#    'start': 10.88,
#    'end': 12.56,
#    'text': " Okay, let's get started.",
#    'tokens': [50908, 1033, 11, 718, 311, 483, 1409, 13, 50992],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 4,
#    'seek': 0,
#    'start': 14.200000000000001,
#    'end': 15.040000000000001,
#    'text': ' Please.',
#    'tokens': [51074, 2555, 13, 51116],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 5,
#    'seek': 0,
#    'start': 15.040000000000001,
#    'end': 15.860000000000001,
#    'text': ' Yes.',
#    'tokens': [51116, 1079, 13, 51157],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 6,
#    'seek': 0,
#    'start': 15.860000000000001,
#    'end': 16.7,
#    'text': ' Hey.',
#    'tokens': [51157, 1911, 13, 51199],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 7,
#    'seek': 0,
#    'start': 16.7,
#    'end': 17.54,
#    'text': " Hi, Tom, welcome to Conan O'Brien.",
#    'tokens': [51199,
#     2421,
#     11,
#     5041,
#     11,
#     2928,
#     281,
#     47691,
#     422,
#     6,
#     47999,
#     13,
#     51241],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 8,
#    'seek': 0,
#    'start': 17.54,
#    'end': 18.36,
#    'text': ' Hello.',
#    'tokens': [51241, 2425, 13, 51282],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 9,
#    'seek': 0,
#    'start': 18.36,
#    'end': 19.56,
#    'text': ' He needs a fan, nice sweater.',
#    'tokens': [51282, 634, 2203, 257, 3429, 11, 1481, 26550, 13, 51342],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 10,
#    'seek': 0,
#    'start': 19.56,
#    'end': 21.1,
#    'text': ' Wow. Thank you.',
#    'tokens': [51342, 3153, 13, 1044, 291, 13, 51419],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 11,
#    'seek': 0,
#    'start': 21.1,
#    'end': 22.22,
#    'text': ' Good job.',
#    'tokens': [51419, 2205, 1691, 13, 51475],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 12,
#    'seek': 0,
#    'start': 22.22,
#    'end': 26.44,
#    'text': ' First of all, Gourley on just being so positive so quickly.',
#    'tokens': [51475,
#     2386,
#     295,
#     439,
#     11,
#     460,
#     396,
#     3420,
#     322,
#     445,
#     885,
#     370,
#     3353,
#     370,
#     2661,
#     13,
#     51686],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 13,
#    'seek': 0,
#    'start': 26.44,
#    'end': 29.2,
#    'text': ' Tom, so nice to see you.',
#    'tokens': [51686, 5041, 11, 370, 1481, 281, 536, 291, 13, 51824],
#    'temperature': 0.0,
#    'avg_logprob': -0.32380155789650095,
#    'compression_ratio': 1.4691943127962086,
#    'no_speech_prob': 0.12563562393188477},
#   {'id': 14,
#    'seek': 2920,
#    'start': 29.2,
#    'end': 30.04,
#    'text': ' I see you have your-',
#    'tokens': [50364, 286, 536, 291, 362, 428, 12, 50406],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 15,
#    'seek': 2920,
#    'start': 30.04,
#    'end': 30.88,
#    'text': ' You too.',
#    'tokens': [50406, 509, 886, 13, 50448],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 16,
#    'seek': 2920,
#    'start': 30.88,
#    'end': 32.28,
#    'text': ' Your Christmas tree in the background.',
#    'tokens': [50448, 2260, 5272, 4230, 294, 264, 3678, 13, 50518],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 17,
#    'seek': 2920,
#    'start': 32.28,
#    'end': 34.04,
#    'text': ' It looks dark where you are.',
#    'tokens': [50518, 467, 1542, 2877, 689, 291, 366, 13, 50606],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 18,
#    'seek': 2920,
#    'start': 34.04,
#    'end': 35.76,
#    'text': " We're in Los Angeles, where are you?",
#    'tokens': [50606, 492, 434, 294, 7632, 12292, 11, 689, 366, 291, 30, 50692],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 19,
#    'seek': 2920,
#    'start': 35.76,
#    'end': 37.64,
#    'text': " I'm Conan from Dublin, Ireland.",
#    'tokens': [50692, 286, 478, 47691, 490, 42323, 11, 15880, 13, 50786],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 20,
#    'seek': 2920,
#    'start': 37.64,
#    'end': 39.24,
#    'text': " Oh, you're in Dublin.",
#    'tokens': [50786, 876, 11, 291, 434, 294, 42323, 13, 50866],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 21,
#    'seek': 2920,
#    'start': 39.24,
#    'end': 41.32,
#    'text': ' Look at that fine Irish cable knit',
#    'tokens': [50866, 2053, 412, 300, 2489, 16801, 8220, 15594, 50970],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 22,
#    'seek': 2920,
#    'start': 41.32,
#    'end': 43.32,
#    'text': ' fisherman sweater and Christmas tree.',
#    'tokens': [50970, 48657, 26550, 293, 5272, 4230, 13, 51070],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 23,
#    'seek': 2920,
#    'start': 43.32,
#    'end': 44.8,
#    'text': " I didn't live in the light.",
#    'tokens': [51070, 286, 994, 380, 1621, 294, 264, 1442, 13, 51144],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 24,
#    'seek': 2920,
#    'start': 44.8,
#    'end': 46.0,
#    'text': ' I just wanna trade places with you.',
#    'tokens': [51144, 286, 445, 1948, 4923, 3190, 365, 291, 13, 51204],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 25,
#    'seek': 2920,
#    'start': 46.0,
#    'end': 48.4,
#    'text': " I'm sorry, Mr. Gourley is making this sound",
#    'tokens': [51204,
#     286,
#     478,
#     2597,
#     11,
#     2221,
#     13,
#     460,
#     396,
#     3420,
#     307,
#     1455,
#     341,
#     1626,
#     51324],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 26,
#    'seek': 2920,
#    'start': 48.4,
#    'end': 50.0,
#    'text': ' like the home shopping network.',
#    'tokens': [51324, 411, 264, 1280, 8688, 3209, 13, 51404],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 27,
#    'seek': 2920,
#    'start': 50.0,
#    'end': 53.760000000000005,
#    'text': ' Tom here is wearing a fine cable net sweater.',
#    'tokens': [51404,
#     5041,
#     510,
#     307,
#     4769,
#     257,
#     2489,
#     8220,
#     2533,
#     26550,
#     13,
#     51592],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 28,
#    'seek': 2920,
#    'start': 53.760000000000005,
#    'end': 54.6,
#    'text': " It's gorgeous.",
#    'tokens': [51592, 467, 311, 12291, 13, 51634],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 29,
#    'seek': 2920,
#    'start': 54.6,
#    'end': 57.8,
#    'text': " It's made of a fine Dublin weave.",
#    'tokens': [51634, 467, 311, 1027, 295, 257, 2489, 42323, 29145, 13, 51794],
#    'temperature': 0.0,
#    'avg_logprob': -0.22169669157539318,
#    'compression_ratio': 1.6644295302013423,
#    'no_speech_prob': 0.003591919085010886},
#   {'id': 30,
#    'seek': 5780,
#    'start': 57.8,
#    'end': 60.519999999999996,
#    'text': " Sir, tell us, and Tom, what's your last name?",
#    'tokens': [50364,
#     6144,
#     11,
#     980,
#     505,
#     11,
#     293,
#     5041,
#     11,
#     437,
#     311,
#     428,
#     1036,
#     1315,
#     30,
#     50500],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 31,
#    'seek': 5780,
#    'start': 60.519999999999996,
#    'end': 61.36,
#    'text': ' Lawler.',
#    'tokens': [50500, 7744, 1918, 13, 50542],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 32,
#    'seek': 5780,
#    'start': 61.36,
#    'end': 64.8,
#    'text': ' Okay, Tom Lawler, calling from or calling,',
#    'tokens': [50542,
#     1033,
#     11,
#     5041,
#     7744,
#     1918,
#     11,
#     5141,
#     490,
#     420,
#     5141,
#     11,
#     50714],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 33,
#    'seek': 5780,
#    'start': 64.8,
#    'end': 67.96,
#    'text': ' I guess zooming in, calling, whatever you wanna say.',
#    'tokens': [50714,
#     286,
#     2041,
#     48226,
#     294,
#     11,
#     5141,
#     11,
#     2035,
#     291,
#     1948,
#     584,
#     13,
#     50872],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 34,
#    'seek': 5780,
#    'start': 67.96,
#    'end': 72.28,
#    'text': ' Appearing to us magically from Dublin.',
#    'tokens': [50872, 41322, 1921, 281, 505, 39763, 490, 42323, 13, 51088],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 35,
#    'seek': 5780,
#    'start': 72.28,
#    'end': 73.28,
#    'text': ' I love Dublin.',
#    'tokens': [51088, 286, 959, 42323, 13, 51138],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 36,
#    'seek': 5780,
#    'start': 73.28,
#    'end': 75.4,
#    'text': " I love the few times I've visited there.",
#    'tokens': [51138,
#     286,
#     959,
#     264,
#     1326,
#     1413,
#     286,
#     600,
#     11220,
#     456,
#     13,
#     51244],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 37,
#    'seek': 5780,
#    'start': 75.4,
#    'end': 77.2,
#    'text': " I've had a fantastic time.",
#    'tokens': [51244, 286, 600, 632, 257, 5456, 565, 13, 51334],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 38,
#    'seek': 5780,
#    'start': 77.2,
#    'end': 78.52,
#    'text': " Yeah, you've been a few times.",
#    'tokens': [51334, 865, 11, 291, 600, 668, 257, 1326, 1413, 13, 51400],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 39,
#    'seek': 5780,
#    'start': 78.52,
#    'end': 80.0,
#    'text': " I've been a few times.",
#    'tokens': [51400, 286, 600, 668, 257, 1326, 1413, 13, 51474],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 40,
#    'seek': 5780,
#    'start': 80.0,
#    'end': 84.36,
#    'text': ' One of the times I went, I met up with a bunch of other,',
#    'tokens': [51474,
#     1485,
#     295,
#     264,
#     1413,
#     286,
#     1437,
#     11,
#     286,
#     1131,
#     493,
#     365,
#     257,
#     3840,
#     295,
#     661,
#     11,
#     51692],
#    'temperature': 0.0,
#    'avg_logprob': -0.14218063354492189,
#    'compression_ratio': 1.6828193832599119,
#    'no_speech_prob': 0.001500868471339345},
#   {'id': 41,
#    'seek': 8436,
#    'start': 84.36,
#    'end': 88.96,
#    'text': ' well, very famous Irish comedians from Ireland',
#    'tokens': [50364,
#     731,
#     11,
#     588,
#     4618,
#     16801,
#     18418,
#     2567,
#     490,
#     15880,
#     50594],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 42,
#    'seek': 8436,
#    'start': 88.96,
#    'end': 92.92,
#    'text': ' who were all hilarious, and we all did a show together',
#    'tokens': [50594,
#     567,
#     645,
#     439,
#     19796,
#     11,
#     293,
#     321,
#     439,
#     630,
#     257,
#     855,
#     1214,
#     50792],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 43,
#    'seek': 8436,
#    'start': 92.92,
#    'end': 95.88,
#    'text': " at the Ambassador's residence in Phoenix Park,",
#    'tokens': [50792, 412, 264, 28506, 311, 19607, 294, 18383, 4964, 11, 50940],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 44,
#    'seek': 8436,
#    'start': 95.88,
#    'end': 97.8,
#    'text': " and I thought these are the funniest people I've ever met,",
#    'tokens': [50940,
#     293,
#     286,
#     1194,
#     613,
#     366,
#     264,
#     42681,
#     561,
#     286,
#     600,
#     1562,
#     1131,
#     11,
#     51036],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 45,
#    'seek': 8436,
#    'start': 97.8,
#    'end': 99.92,
#    'text': ' and then all of us got into a cab',
#    'tokens': [51036, 293, 550, 439, 295, 505, 658, 666, 257, 5487, 51142],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 46,
#    'seek': 8436,
#    'start': 99.92,
#    'end': 102.2,
#    'text': ' to go into Dublin to get a drink,',
#    'tokens': [51142, 281, 352, 666, 42323, 281, 483, 257, 2822, 11, 51256],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 47,
#    'seek': 8436,
#    'start': 102.2,
#    'end': 104.4,
#    'text': ' and the cabbie was funnier than all of us,',
#    'tokens': [51256,
#     293,
#     264,
#     5487,
#     7392,
#     390,
#     1019,
#     19165,
#     813,
#     439,
#     295,
#     505,
#     11,
#     51366],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 48,
#    'seek': 8436,
#    'start': 104.4,
#    'end': 107.36,
#    'text': " and I thought that's Dublin.",
#    'tokens': [51366, 293, 286, 1194, 300, 311, 42323, 13, 51514],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 49,
#    'seek': 8436,
#    'start': 107.36,
#    'end': 110.24,
#    'text': " There's just everyone that's just super high",
#    'tokens': [51514, 821, 311, 445, 1518, 300, 311, 445, 1687, 1090, 51658],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 50,
#    'seek': 8436,
#    'start': 110.24,
#    'end': 111.96000000000001,
#    'text': ' professional level funny.',
#    'tokens': [51658, 4843, 1496, 4074, 13, 51744],
#    'temperature': 0.0,
#    'avg_logprob': -0.14570168204929518,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 0.0008292720303870738},
#   {'id': 51,
#    'seek': 11196,
#    'start': 111.96,
#    'end': 115.91999999999999,
#    'text': ' So no pressure on me then for the rest of this interview.',
#    'tokens': [50364,
#     407,
#     572,
#     3321,
#     322,
#     385,
#     550,
#     337,
#     264,
#     1472,
#     295,
#     341,
#     4049,
#     13,
#     50562],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 52,
#    'seek': 11196,
#    'start': 115.91999999999999,
#    'end': 116.75999999999999,
#    'text': ' Well done.',
#    'tokens': [50562, 1042, 1096, 13, 50604],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 53,
#    'seek': 11196,
#    'start': 119.03999999999999,
#    'end': 120.91999999999999,
#    'text': " Well, we can always say later on that you're,",
#    'tokens': [50718,
#     1042,
#     11,
#     321,
#     393,
#     1009,
#     584,
#     1780,
#     322,
#     300,
#     291,
#     434,
#     11,
#     50812],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 54,
#    'seek': 11196,
#    'start': 120.91999999999999,
#    'end': 122.75999999999999,
#    'text': " you know, you're going through a depressive period,",
#    'tokens': [50812,
#     291,
#     458,
#     11,
#     291,
#     434,
#     516,
#     807,
#     257,
#     1367,
#     22733,
#     2896,
#     11,
#     50904],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 55,
#    'seek': 11196,
#    'start': 122.75999999999999,
#    'end': 125.32,
#    'text': ' you know, and so that gets you off the hook.',
#    'tokens': [50904,
#     291,
#     458,
#     11,
#     293,
#     370,
#     300,
#     2170,
#     291,
#     766,
#     264,
#     6328,
#     13,
#     51032],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 56,
#    'seek': 11196,
#    'start': 125.32,
#    'end': 127.44,
#    'text': ' Tom, tell me a little bit about yourself.',
#    'tokens': [51032, 5041, 11, 980, 385, 257, 707, 857, 466, 1803, 13, 51138],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 57,
#    'seek': 11196,
#    'start': 128.79999999999998,
#    'end': 131.4,
#    'text': ' Well, so I live in Dublin, as you know,',
#    'tokens': [51206,
#     1042,
#     11,
#     370,
#     286,
#     1621,
#     294,
#     42323,
#     11,
#     382,
#     291,
#     458,
#     11,
#     51336],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 58,
#    'seek': 11196,
#    'start': 131.4,
#    'end': 134.64,
#    'text': ' and I right now am the co-director of a festival',
#    'tokens': [51336,
#     293,
#     286,
#     558,
#     586,
#     669,
#     264,
#     598,
#     12,
#     18267,
#     1672,
#     295,
#     257,
#     12091,
#     51498],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 59,
#    'seek': 11196,
#    'start': 134.64,
#    'end': 137.0,
#    'text': ' here in Dublin that the city started a number of years ago',
#    'tokens': [51498,
#     510,
#     294,
#     42323,
#     300,
#     264,
#     2307,
#     1409,
#     257,
#     1230,
#     295,
#     924,
#     2057,
#     51616],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 60,
#    'seek': 11196,
#    'start': 137.0,
#    'end': 138.64,
#    'text': ' called Bram Stoker Festival,',
#    'tokens': [51616, 1219, 1603, 335, 745, 16722, 16512, 11, 51698],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 61,
#    'seek': 11196,
#    'start': 138.64,
#    'end': 141.64,
#    'text': ' which is basically a way of us celebrating',
#    'tokens': [51698, 597, 307, 1936, 257, 636, 295, 505, 15252, 51848],
#    'temperature': 0.0,
#    'avg_logprob': -0.16185760498046875,
#    'compression_ratio': 1.6832740213523132,
#    'no_speech_prob': 0.00016600539674982429},
#   {'id': 62,
#    'seek': 14164,
#    'start': 141.64,
#    'end': 143.67999999999998,
#    'text': ' the life and legacy and work of Bram Stoker,',
#    'tokens': [50364,
#     264,
#     993,
#     293,
#     11711,
#     293,
#     589,
#     295,
#     1603,
#     335,
#     745,
#     16722,
#     11,
#     50466],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 63,
#    'seek': 14164,
#    'start': 143.67999999999998,
#    'end': 144.79999999999998,
#    'text': ' who wrote Dracula.',
#    'tokens': [50466, 567, 4114, 48950, 13, 50522],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 64,
#    'seek': 14164,
#    'start': 144.79999999999998,
#    'end': 147.11999999999998,
#    'text': ' Yep, and so this is interesting to me',
#    'tokens': [50522, 7010, 11, 293, 370, 341, 307, 1880, 281, 385, 50638],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 65,
#    'seek': 14164,
#    'start': 147.11999999999998,
#    'end': 148.83999999999997,
#    'text': " because I don't have to say, I admit,",
#    'tokens': [50638,
#     570,
#     286,
#     500,
#     380,
#     362,
#     281,
#     584,
#     11,
#     286,
#     9796,
#     11,
#     50724],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 66,
#    'seek': 14164,
#    'start': 148.83999999999997,
#    'end': 153.55999999999997,
#    'text': " I don't know much about Bram Stoker, obviously.",
#    'tokens': [50724,
#     286,
#     500,
#     380,
#     458,
#     709,
#     466,
#     1603,
#     335,
#     745,
#     16722,
#     11,
#     2745,
#     13,
#     50960],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 67,
#    'seek': 14164,
#    'start': 153.55999999999997,
#    'end': 154.67999999999998,
#    'text': ' His work is very famous,',
#    'tokens': [50960, 2812, 589, 307, 588, 4618, 11, 51016],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 68,
#    'seek': 14164,
#    'start': 154.67999999999998,
#    'end': 158.48,
#    'text': " but I don't know much about the man himself.",
#    'tokens': [51016,
#     457,
#     286,
#     500,
#     380,
#     458,
#     709,
#     466,
#     264,
#     587,
#     3647,
#     13,
#     51206],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 69,
#    'seek': 14164,
#    'start': 158.48,
#    'end': 159.6,
#    'text': ' Was he Irish?',
#    'tokens': [51206, 3027, 415, 16801, 30, 51262],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 70,
#    'seek': 14164,
#    'start': 160.88,
#    'end': 162.92,
#    'text': ' Yeah, he was Irish, and I think part of that,',
#    'tokens': [51326,
#     865,
#     11,
#     415,
#     390,
#     16801,
#     11,
#     293,
#     286,
#     519,
#     644,
#     295,
#     300,
#     11,
#     51428],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 71,
#    'seek': 14164,
#    'start': 162.92,
#    'end': 165.11999999999998,
#    'text': ' one of the big reasons the festival was started',
#    'tokens': [51428, 472, 295, 264, 955, 4112, 264, 12091, 390, 1409, 51538],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 72,
#    'seek': 14164,
#    'start': 165.11999999999998,
#    'end': 168.92,
#    'text': ' was I guess to kind of reclaim him as an Irish author, right?',
#    'tokens': [51538,
#     390,
#     286,
#     2041,
#     281,
#     733,
#     295,
#     40074,
#     796,
#     382,
#     364,
#     16801,
#     3793,
#     11,
#     558,
#     30,
#     51728],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 73,
#    'seek': 14164,
#    'start': 168.92,
#    'end': 171.6,
#    'text': ' So everybody knows Joyce and Beckett as Irish authors,',
#    'tokens': [51728,
#     407,
#     2201,
#     3255,
#     40044,
#     293,
#     19184,
#     3093,
#     382,
#     16801,
#     16552,
#     11,
#     51862],
#    'temperature': 0.0,
#    'avg_logprob': -0.10857617855072021,
#    'compression_ratio': 1.6794425087108014,
#    'no_speech_prob': 5.092852006782778e-06},
#   {'id': 74,
#    'seek': 17160,
#    'start': 172.6,
#    'end': 173.76,
#    'text': ' but I think a lot of people had kind of assumed',
#    'tokens': [50414,
#     457,
#     286,
#     519,
#     257,
#     688,
#     295,
#     561,
#     632,
#     733,
#     295,
#     15895,
#     50472],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 75,
#    'seek': 17160,
#    'start': 173.76,
#    'end': 175.56,
#    'text': ' or thought that Bram Stoker was British,',
#    'tokens': [50472,
#     420,
#     1194,
#     300,
#     1603,
#     335,
#     745,
#     16722,
#     390,
#     6221,
#     11,
#     50562],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 76,
#    'seek': 17160,
#    'start': 175.56,
#    'end': 179.48,
#    'text': ' and the Brits have a long history of claiming Irish people',
#    'tokens': [50562,
#     293,
#     264,
#     1603,
#     1208,
#     362,
#     257,
#     938,
#     2503,
#     295,
#     19232,
#     16801,
#     561,
#     50758],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 77,
#    'seek': 17160,
#    'start': 179.48,
#    'end': 181.2,
#    'text': ' as their own when they become very successful,',
#    'tokens': [50758, 382, 641, 1065, 562, 436, 1813, 588, 4406, 11, 50844],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 78,
#    'seek': 17160,
#    'start': 181.2,
#    'end': 183.16,
#    'text': ' so it was kind of a way of taking it back',
#    'tokens': [50844,
#     370,
#     309,
#     390,
#     733,
#     295,
#     257,
#     636,
#     295,
#     1940,
#     309,
#     646,
#     50942],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 79,
#    'seek': 17160,
#    'start': 183.16,
#    'end': 188.16,
#    'text': ' and kind of reclaiming him as a Dublin-born Irish writer, yeah.',
#    'tokens': [50942,
#     293,
#     733,
#     295,
#     40074,
#     278,
#     796,
#     382,
#     257,
#     42323,
#     12,
#     10324,
#     16801,
#     9936,
#     11,
#     1338,
#     13,
#     51192],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 80,
#    'seek': 17160,
#    'start': 188.35999999999999,
#    'end': 192.04,
#    'text': " That's actually very, I mean, that's fascinating to me.",
#    'tokens': [51202,
#     663,
#     311,
#     767,
#     588,
#     11,
#     286,
#     914,
#     11,
#     300,
#     311,
#     10343,
#     281,
#     385,
#     13,
#     51386],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 81,
#    'seek': 17160,
#    'start': 192.04,
#    'end': 194.92,
#    'text': " You may have heard me say, I've said it many times,",
#    'tokens': [51386,
#     509,
#     815,
#     362,
#     2198,
#     385,
#     584,
#     11,
#     286,
#     600,
#     848,
#     309,
#     867,
#     1413,
#     11,
#     51530],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 82,
#    'seek': 17160,
#    'start': 194.92,
#    'end': 198.16,
#    'text': " because it's kind of fascinating slash sad to me,",
#    'tokens': [51530,
#     570,
#     309,
#     311,
#     733,
#     295,
#     10343,
#     17330,
#     4227,
#     281,
#     385,
#     11,
#     51692],
#    'temperature': 0.0,
#    'avg_logprob': -0.09551071375608444,
#    'compression_ratio': 1.6962962962962962,
#    'no_speech_prob': 9.815920748224016e-06},
#   {'id': 83,
#    'seek': 19816,
#    'start': 198.16,
#    'end': 202.56,
#    'text': ' but my people emigrated from Ireland',
#    'tokens': [50364, 457, 452, 561, 846, 328, 5468, 490, 15880, 50584],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 84,
#    'seek': 19816,
#    'start': 202.56,
#    'end': 203.72,
#    'text': ' in the late 19th century,',
#    'tokens': [50584, 294, 264, 3469, 1294, 392, 4901, 11, 50642],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 85,
#    'seek': 19816,
#    'start': 203.72,
#    'end': 205.68,
#    'text': " and we've been living in central Massachusetts,",
#    'tokens': [50642, 293, 321, 600, 668, 2647, 294, 5777, 19979, 11, 50740],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 86,
#    'seek': 19816,
#    'start': 205.68,
#    'end': 208.4,
#    'text': " and I'm still genetically 100% Irish,",
#    'tokens': [50740, 293, 286, 478, 920, 37582, 2319, 4, 16801, 11, 50876],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 87,
#    'seek': 19816,
#    'start': 209.56,
#    'end': 211.32,
#    'text': ' which is I think tragic.',
#    'tokens': [50934, 597, 307, 286, 519, 20385, 13, 51022],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 88,
#    'seek': 19816,
#    'start': 211.32,
#    'end': 212.92,
#    'text': ' Tom, will you please reclaim him?',
#    'tokens': [51022, 5041, 11, 486, 291, 1767, 40074, 796, 30, 51102],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 89,
#    'seek': 19816,
#    'start': 212.92,
#    'end': 213.76,
#    'text': ' Yeah.',
#    'tokens': [51102, 865, 13, 51144],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 90,
#    'seek': 19816,
#    'start': 213.76,
#    'end': 214.57999999999998,
#    'text': ' Wait.',
#    'tokens': [51144, 3802, 13, 51185],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 91,
#    'seek': 19816,
#    'start': 214.57999999999998,
#    'end': 219.57999999999998,
#    'text': ' And Americans desperately want me to be reclaimed,',
#    'tokens': [51185,
#     400,
#     6280,
#     23726,
#     528,
#     385,
#     281,
#     312,
#     850,
#     22642,
#     11,
#     51435],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 92,
#    'seek': 19816,
#    'start': 220.04,
#    'end': 223.07999999999998,
#    'text': ' and they mean taken back to Ireland and kept there.',
#    'tokens': [51458,
#     293,
#     436,
#     914,
#     2726,
#     646,
#     281,
#     15880,
#     293,
#     4305,
#     456,
#     13,
#     51610],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 93,
#    'seek': 19816,
#    'start': 223.07999999999998,
#    'end': 224.92,
#    'text': " Well, we'd be delighted to reclaim you",
#    'tokens': [51610, 1042, 11, 321, 1116, 312, 18783, 281, 40074, 291, 51702],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 94,
#    'seek': 19816,
#    'start': 224.92,
#    'end': 226.88,
#    'text': ' and have you at the festival anytime, or in Dublin.',
#    'tokens': [51702,
#     293,
#     362,
#     291,
#     412,
#     264,
#     12091,
#     13038,
#     11,
#     420,
#     294,
#     42323,
#     13,
#     51800],
#    'temperature': 0.0,
#    'avg_logprob': -0.13400802291741892,
#    'compression_ratio': 1.5353159851301115,
#    'no_speech_prob': 0.0005789840361103415},
#   {'id': 95,
#    'seek': 22688,
#    'start': 226.88,
#    'end': 228.24,
#    'text': " I mean, you're hugely popular.",
#    'tokens': [50364, 286, 914, 11, 291, 434, 27417, 3743, 13, 50432],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 96,
#    'seek': 22688,
#    'start': 228.24,
#    'end': 230.35999999999999,
#    'text': ' I feel like lots of the friends or the fans',
#    'tokens': [50432,
#     286,
#     841,
#     411,
#     3195,
#     295,
#     264,
#     1855,
#     420,
#     264,
#     4499,
#     50538],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 97,
#    'seek': 22688,
#    'start': 230.35999999999999,
#    'end': 232.16,
#    'text': ' on this podcast are coming from Ireland as well, right?',
#    'tokens': [50538,
#     322,
#     341,
#     7367,
#     366,
#     1348,
#     490,
#     15880,
#     382,
#     731,
#     11,
#     558,
#     30,
#     50628],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 98,
#    'seek': 22688,
#    'start': 232.16,
#    'end': 233.0,
#    'text': " You've got to go there.",
#    'tokens': [50628, 509, 600, 658, 281, 352, 456, 13, 50670],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 99,
#    'seek': 22688,
#    'start': 233.0,
#    'end': 234.76,
#    'text': " No, it's funny, we do have,",
#    'tokens': [50670, 883, 11, 309, 311, 4074, 11, 321, 360, 362, 11, 50758],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 100,
#    'seek': 22688,
#    'start': 234.76,
#    'end': 239.76,
#    'text': ' I do get recognition from Irish people for the TV show,',
#    'tokens': [50758,
#     286,
#     360,
#     483,
#     11150,
#     490,
#     16801,
#     561,
#     337,
#     264,
#     3558,
#     855,
#     11,
#     51008],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 101,
#    'seek': 22688,
#    'start': 241.04,
#    'end': 245.0,
#    'text': ' but also a lot from the podcast, which is very nice.',
#    'tokens': [51072,
#     457,
#     611,
#     257,
#     688,
#     490,
#     264,
#     7367,
#     11,
#     597,
#     307,
#     588,
#     1481,
#     13,
#     51270],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 102,
#    'seek': 22688,
#    'start': 245.0,
#    'end': 247.48,
#    'text': " So I'd love to go back there,",
#    'tokens': [51270, 407, 286, 1116, 959, 281, 352, 646, 456, 11, 51394],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 103,
#    'seek': 22688,
#    'start': 247.48,
#    'end': 250.6,
#    'text': " and I'd love to reconnect,",
#    'tokens': [51394, 293, 286, 1116, 959, 281, 30095, 11, 51550],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 104,
#    'seek': 22688,
#    'start': 250.6,
#    'end': 253.07999999999998,
#    'text': ' because I think it would be lovely.',
#    'tokens': [51550, 570, 286, 519, 309, 576, 312, 7496, 13, 51674],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 105,
#    'seek': 22688,
#    'start': 253.07999999999998,
#    'end': 255.14,
#    'text': " That's a word that I hear a lot.",
#    'tokens': [51674, 663, 311, 257, 1349, 300, 286, 1568, 257, 688, 13, 51777],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 106,
#    'seek': 22688,
#    'start': 255.14,
#    'end': 255.98,
#    'text': ' Lovely.',
#    'tokens': [51777, 33925, 13, 51819],
#    'temperature': 0.0,
#    'avg_logprob': -0.13484039591319524,
#    'compression_ratio': 1.5977443609022557,
#    'no_speech_prob': 0.0007551604649052024},
#   {'id': 107,
#    'seek': 25598,
#    'start': 256.38,
#    'end': 257.86,
#    'text': " I've heard that in Ireland, they say,",
#    'tokens': [50384, 286, 600, 2198, 300, 294, 15880, 11, 436, 584, 11, 50458],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 108,
#    'seek': 25598,
#    'start': 257.86,
#    'end': 259.26,
#    'text': " isn't that lovely?",
#    'tokens': [50458, 1943, 380, 300, 7496, 30, 50528],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 109,
#    'seek': 25598,
#    'start': 259.26,
#    'end': 262.42,
#    'text': " Also, they say, correct me if I'm wrong, Tom,",
#    'tokens': [50528,
#     2743,
#     11,
#     436,
#     584,
#     11,
#     3006,
#     385,
#     498,
#     286,
#     478,
#     2085,
#     11,
#     5041,
#     11,
#     50686],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 110,
#    'seek': 25598,
#    'start': 262.42,
#    'end': 264.58,
#    'text': ' in America, people say um.',
#    'tokens': [50686, 294, 3374, 11, 561, 584, 1105, 13, 50794],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 111,
#    'seek': 25598,
#    'start': 264.58,
#    'end': 268.82,
#    'text': ' So if you ask me a question, I say, um, yeah.',
#    'tokens': [50794,
#     407,
#     498,
#     291,
#     1029,
#     385,
#     257,
#     1168,
#     11,
#     286,
#     584,
#     11,
#     1105,
#     11,
#     1338,
#     13,
#     51006],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 112,
#    'seek': 25598,
#    'start': 268.82,
#    'end': 270.62,
#    'text': ' I live near the Volkswagen dealership,',
#    'tokens': [51006, 286, 1621, 2651, 264, 39856, 25955, 1210, 11, 51096],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 113,
#    'seek': 25598,
#    'start': 270.62,
#    'end': 272.02,
#    'text': ' but about two blocks away.',
#    'tokens': [51096, 457, 466, 732, 8474, 1314, 13, 51166],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 114,
#    'seek': 25598,
#    'start': 273.26,
#    'end': 275.86,
#    'text': " The people I've met in Dublin say M, E, M.",
#    'tokens': [51228,
#     440,
#     561,
#     286,
#     600,
#     1131,
#     294,
#     42323,
#     584,
#     376,
#     11,
#     462,
#     11,
#     376,
#     13,
#     51358],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 115,
#    'seek': 25598,
#    'start': 275.86,
#    'end': 276.94,
#    'text': ' Yeah, Gretan Norton.',
#    'tokens': [51358, 865, 11, 460, 1505, 282, 426, 36184, 13, 51412],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 116,
#    'seek': 25598,
#    'start': 276.94,
#    'end': 278.18,
#    'text': ' Yeah, have you noticed that?',
#    'tokens': [51412, 865, 11, 362, 291, 5694, 300, 30, 51474],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 117,
#    'seek': 25598,
#    'start': 278.18,
#    'end': 279.98,
#    'text': " Yeah, actually, yeah, it's funny you say that,",
#    'tokens': [51474,
#     865,
#     11,
#     767,
#     11,
#     1338,
#     11,
#     309,
#     311,
#     4074,
#     291,
#     584,
#     300,
#     11,
#     51564],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
#    'compression_ratio': 1.5441176470588236,
#    'no_speech_prob': 0.001986683113500476},
#   {'id': 118,
#    'seek': 25598,
#    'start': 279.98,
#    'end': 281.09999999999997,
#    'text': ' because um.',
#    'tokens': [51564, 570, 1105, 13, 51620],
#    'temperature': 0.0,
#    'avg_logprob': -0.29596143019826787,
# ...
#    'no_speech_prob': 0.00032502529211342335},
#   {'id': 580,
#    'seek': 123128,
#    'start': 1257.24,
#    'end': 1259.6,
#    'text': " Okay, now you're just poking fun and that's ridiculous.",
#    'tokens': [51662,
#     1033,
#     11,
#     586,
#     291,
#     434,
#     445,
#     42684,
#     1019,
#     293,
#     300,
#     311,
#     11083,
#     13,
#     51780],
#    'temperature': 0.0,
#    'avg_logprob': -0.24373144732263988,
#    'compression_ratio': 1.6941580756013745,
#    'no_speech_prob': 0.00032502529211342335},
#   {'id': 581,
#    'seek': 125960,
#    'start': 1259.6,
#    'end': 1261.3999999999999,
#    'text': " Well, I'm really happy with myself.",
#    'tokens': [50364, 1042, 11, 286, 478, 534, 2055, 365, 2059, 13, 50454],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 582,
#    'seek': 125960,
#    'start': 1261.3999999999999,
#    'end': 1263.28,
#    'text': ' Tom, thank you.',
#    'tokens': [50454, 5041, 11, 1309, 291, 13, 50548],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 583,
#    'seek': 125960,
#    'start': 1263.28,
#    'end': 1264.32,
#    'text': ' Thank you for reaching out.',
#    'tokens': [50548, 1044, 291, 337, 9906, 484, 13, 50600],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 584,
#    'seek': 125960,
#    'start': 1264.32,
#    'end': 1265.1599999999999,
#    'text': ' Thank you.',
#    'tokens': [50600, 1044, 291, 13, 50642],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 585,
#    'seek': 125960,
#    'start': 1265.1599999999999,
#    'end': 1267.24,
#    'text': ' Speaking to us, I will take it to heart',
#    'tokens': [50642,
#     13069,
#     281,
#     505,
#     11,
#     286,
#     486,
#     747,
#     309,
#     281,
#     1917,
#     50746],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 586,
#    'seek': 125960,
#    'start': 1267.24,
#    'end': 1269.56,
#    'text': ' this whole Bram Stoker controversy.',
#    'tokens': [50746, 341, 1379, 1603, 335, 745, 16722, 22976, 13, 50862],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 587,
#    'seek': 125960,
#    'start': 1269.56,
#    'end': 1273.56,
#    'text': ' I will work in the fact that Bram Stoker is Irish',
#    'tokens': [50862,
#     286,
#     486,
#     589,
#     294,
#     264,
#     1186,
#     300,
#     1603,
#     335,
#     745,
#     16722,
#     307,
#     16801,
#     51062],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 588,
#    'seek': 125960,
#    'start': 1273.56,
#    'end': 1276.48,
#    'text': ' in every conversation that I can in the most awkward way.',
#    'tokens': [51062,
#     294,
#     633,
#     3761,
#     300,
#     286,
#     393,
#     294,
#     264,
#     881,
#     11411,
#     636,
#     13,
#     51208],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 589,
#    'seek': 125960,
#    'start': 1276.48,
#    'end': 1277.32,
#    'text': ' And I will fight this-',
#    'tokens': [51208, 400, 286, 486, 2092, 341, 12, 51250],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 590,
#    'seek': 125960,
#    'start': 1277.32,
#    'end': 1278.52,
#    'text': " Thank you, I'd really appreciate it.",
#    'tokens': [51250, 1044, 291, 11, 286, 1116, 534, 4449, 309, 13, 51310],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 591,
#    'seek': 125960,
#    'start': 1278.52,
#    'end': 1281.24,
#    'text': ' All right, well, happy holidays.',
#    'tokens': [51310, 1057, 558, 11, 731, 11, 2055, 15734, 13, 51446],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 592,
#    'seek': 125960,
#    'start': 1281.24,
#    'end': 1282.08,
#    'text': ' Yeah, you too.',
#    'tokens': [51446, 865, 11, 291, 886, 13, 51488],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 593,
#    'seek': 125960,
#    'start': 1282.08,
#    'end': 1282.9199999999998,
#    'text': ' And thank you so much.',
#    'tokens': [51488, 400, 1309, 291, 370, 709, 13, 51530],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 594,
#    'seek': 125960,
#    'start': 1282.9199999999998,
#    'end': 1283.74,
#    'text': ' Take care.',
#    'tokens': [51530, 3664, 1127, 13, 51571],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 595,
#    'seek': 125960,
#    'start': 1283.74,
#    'end': 1284.58,
#    'text': ' Thank you guys, thanks very much.',
#    'tokens': [51571, 1044, 291, 1074, 11, 3231, 588, 709, 13, 51613],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 596,
#    'seek': 125960,
#    'start': 1284.58,
#    'end': 1285.3999999999999,
#    'text': ' Thank you. Bye-bye.',
#    'tokens': [51613, 1044, 291, 13, 4621, 12, 6650, 13, 51654],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 597,
#    'seek': 125960,
#    'start': 1285.3999999999999,
#    'end': 1286.24,
#    'text': ' Bye-bye.',
#    'tokens': [51654, 4621, 12, 6650, 13, 51696],
#    'temperature': 0.0,
#    'avg_logprob': -0.14534210253365432,
#    'compression_ratio': 1.8143939393939394,
#    'no_speech_prob': 0.000855740625411272},
#   {'id': 598,
#    'seek': 128624,
#    'start': 1286.92,
#    'end': 1288.8,
#    'text': " Conan O'Brien needs a friend.",
#    'tokens': [50398, 47691, 422, 6, 47999, 2203, 257, 1277, 13, 50492],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 599,
#    'seek': 128624,
#    'start': 1288.8,
#    'end': 1292.24,
#    'text': " With Conan O'Brien, Sonam Ovsessian, and Matt Gourley.",
#    'tokens': [50492,
#     2022,
#     47691,
#     422,
#     6,
#     47999,
#     11,
#     5185,
#     335,
#     422,
#     36959,
#     442,
#     952,
#     11,
#     293,
#     7397,
#     460,
#     396,
#     3420,
#     13,
#     50664],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 600,
#    'seek': 128624,
#    'start': 1292.24,
#    'end': 1294.0,
#    'text': ' Produced by me, Matt Gourley.',
#    'tokens': [50664,
#     11793,
#     1232,
#     538,
#     385,
#     11,
#     7397,
#     460,
#     396,
#     3420,
#     13,
#     50752],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 601,
#    'seek': 128624,
#    'start': 1294.0,
#    'end': 1296.6,
#    'text': ' Executive produced by Adam Sachs, Nick Leal,',
#    'tokens': [50752,
#     20658,
#     7126,
#     538,
#     7938,
#     25626,
#     82,
#     11,
#     9449,
#     1456,
#     304,
#     11,
#     50882],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 602,
#    'seek': 128624,
#    'start': 1296.6,
#    'end': 1298.36,
#    'text': ' and Jeff Ross at Team Coco,',
#    'tokens': [50882, 293, 7506, 16140, 412, 7606, 29787, 11, 50970],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 603,
#    'seek': 128624,
#    'start': 1298.36,
#    'end': 1301.52,
#    'text': ' and Colin Anderson and Cody Fisher at Earwolf.',
#    'tokens': [50970,
#     293,
#     29253,
#     18768,
#     293,
#     34524,
#     26676,
#     412,
#     3929,
#     34763,
#     13,
#     51128],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 604,
#    'seek': 128624,
#    'start': 1301.52,
#    'end': 1303.48,
#    'text': ' Theme song by The White Stripes.',
#    'tokens': [51128, 42428, 2153, 538, 440, 5552, 20390, 5190, 13, 51226],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 605,
#    'seek': 128624,
#    'start': 1303.48,
#    'end': 1305.52,
#    'text': ' Incidental music by Jimmy Vivino.',
#    'tokens': [51226, 7779, 47023, 1318, 538, 15709, 28188, 2982, 13, 51328],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 606,
#    'seek': 128624,
#    'start': 1305.52,
#    'end': 1306.52,
#    'text': ' Take it away, Jimmy.',
#    'tokens': [51328, 3664, 309, 1314, 11, 15709, 13, 51378],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 607,
#    'seek': 128624,
#    'start': 1309.32,
#    'end': 1311.36,
#    'text': ' Our supervising producer is Aaron Blair,',
#    'tokens': [51518, 2621, 37971, 3436, 12314, 307, 14018, 42157, 11, 51620],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 608,
#    'seek': 128624,
#    'start': 1311.36,
#    'end': 1314.02,
#    'text': ' and our associate talent producer is Jennifer Samples.',
#    'tokens': [51620,
#     293,
#     527,
#     14644,
#     8301,
#     12314,
#     307,
#     14351,
#     4832,
#     2622,
#     13,
#     51753],
#    'temperature': 0.0,
#    'avg_logprob': -0.16795047493868095,
#    'compression_ratio': 1.5833333333333333,
#    'no_speech_prob': 0.3770410418510437},
#   {'id': 609,
#    'seek': 131402,
#    'start': 1314.06,
#    'end': 1316.02,
#    'text': ' Engineering by Eduardo Perez.',
#    'tokens': [50366, 16215, 538, 45819, 47317, 13, 50464],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 610,
#    'seek': 131402,
#    'start': 1316.02,
#    'end': 1318.54,
#    'text': ' Additional production support by Mars Melnick.',
#    'tokens': [50464, 44272, 4265, 1406, 538, 9692, 7375, 77, 618, 13, 50590],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 611,
#    'seek': 131402,
#    'start': 1318.54,
#    'end': 1322.54,
#    'text': ' Talent booking by Paula Davis, Gina Battista, and Brit Kahn.',
#    'tokens': [50590,
#     44081,
#     34424,
#     538,
#     31663,
#     15658,
#     11,
#     34711,
#     29439,
#     5236,
#     11,
#     293,
#     4760,
#     591,
#     12140,
#     13,
#     50790],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 612,
#    'seek': 131402,
#    'start': 1322.54,
#    'end': 1324.96,
#    'text': ' You can rate and review this show on Apple Podcasts,',
#    'tokens': [50790,
#     509,
#     393,
#     3314,
#     293,
#     3131,
#     341,
#     855,
#     322,
#     6373,
#     29972,
#     82,
#     11,
#     50911],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 613,
#    'seek': 131402,
#    'start': 1324.96,
#    'end': 1327.82,
#    'text': ' and you might find your review read on a future episode.',
#    'tokens': [50911,
#     293,
#     291,
#     1062,
#     915,
#     428,
#     3131,
#     1401,
#     322,
#     257,
#     2027,
#     3500,
#     13,
#     51054],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 614,
#    'seek': 131402,
#    'start': 1327.82,
#    'end': 1329.1399999999999,
#    'text': ' Got a question for Conan?',
#    'tokens': [51054, 5803, 257, 1168, 337, 47691, 30, 51120],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 615,
#    'seek': 131402,
#    'start': 1329.1399999999999,
#    'end': 1333.46,
#    'text': ' Call the Team Coco hotline at 669-587-2847',
#    'tokens': [51120,
#     7807,
#     264,
#     7606,
#     29787,
#     2368,
#     1889,
#     412,
#     21126,
#     24,
#     12,
#     20419,
#     22,
#     12,
#     11205,
#     14060,
#     51336],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 616,
#    'seek': 131402,
#    'start': 1333.46,
#    'end': 1334.5,
#    'text': ' and leave a message.',
#    'tokens': [51336, 293, 1856, 257, 3636, 13, 51388],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 617,
#    'seek': 131402,
#    'start': 1334.5,
#    'end': 1336.74,
#    'text': ' It too could be featured on a future episode.',
#    'tokens': [51388,
#     467,
#     886,
#     727,
#     312,
#     13822,
#     322,
#     257,
#     2027,
#     3500,
#     13,
#     51500],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 618,
#    'seek': 131402,
#    'start': 1336.74,
#    'end': 1337.86,
#    'text': " And if you haven't already,",
#    'tokens': [51500, 400, 498, 291, 2378, 380, 1217, 11, 51556],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 619,
#    'seek': 131402,
#    'start': 1337.86,
#    'end': 1340.1399999999999,
#    'text': " please subscribe to Conan O'Brien Needs a Friend",
#    'tokens': [51556,
#     1767,
#     3022,
#     281,
#     47691,
#     422,
#     6,
#     47999,
#     1734,
#     5147,
#     257,
#     22812,
#     51670],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 620,
#    'seek': 131402,
#    'start': 1340.1399999999999,
#    'end': 1342.62,
#    'text': ' wherever fine podcasts are downloaded.',
#    'tokens': [51670, 8660, 2489, 24045, 366, 21748, 13, 51794],
#    'temperature': 0.0,
#    'avg_logprob': -0.11963711614194124,
#    'compression_ratio': 1.549689440993789,
#    'no_speech_prob': 0.1729779690504074},
#   {'id': 621,
#    'seek': 134402,
#    'start': 1344.02,
#    'end': 1347.02,
#    'text': ' This has been a Team Coco production',
#    'tokens': [50364, 639, 575, 668, 257, 7606, 29787, 4265, 50514],
#    'temperature': 0.0,
#    'avg_logprob': -0.4807692633734809,
#    'compression_ratio': 0.9558823529411765,
#    'no_speech_prob': 0.006484341807663441},
#   {'id': 622,
#    'seek': 134402,
#    'start': 1347.02,
#    'end': 1349.02,
#    'text': ' in association with Earwolf.',
#    'tokens': [50514, 294, 14598, 365, 3929, 34763, 13, 50614],
#    'temperature': 0.0,
#    'avg_logprob': -0.4807692633734809,
#    'compression_ratio': 0.9558823529411765,
#    'no_speech_prob': 0.006484341807663441}],
#  'language': 'english'}

# %%
import json
with open('sub.vtt', "w") as txt:
  json.dump(result, txt)

# %%
from whisper.utils import WriteVTT, WriteSRT,WriteJSON

# %%
writer = whisper.utils.get_writer("srt", "")
writer(result, "new.srt")
